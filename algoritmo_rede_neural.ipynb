# %% [markdown]
# <!-- Projeto adaptado de um desenvolvido na Data Science Academy - www.datascienceacademy.com.br -->
#
# # Algoritmo de Rede Neural usando Python "puro"
#
# Esse projeto surgiu durante as aulas da [Pós-Graduação em Ciência de Dados da Data Science Academy](https://www.datascienceacademy.com.br/bundle/pos-graduacao-em-ciencia-de-dados), onde o instrutor Daniel nos guiou na construção de um algoritmo de Rede Neural com o NumPy. NumPy, claro, facilita a vida na hora de lidar com a matemática pesada de redes neurais.
#
# Mas eu quis ir além e me desafiar: resolvi reescrever o algoritmo em **Python "puro"**, sem usar bibliotecas externas (nem mesmo o NumPy) e evitando até funções prontas do próprio Python (as built-ins). A ideia foi simplificar para entender tudo que está rolando nos bastidores.
#
# Para ajudar a acompanhar, o código faz prints em cada etapa, mostrando o que está acontecendo. O objetivo é entender melhor como uma rede neural funciona de ponta a ponta e, de quebra, se divertir um pouco explorando o conceito de Python "puro."
#
# Espero que curtam!

# %% [markdown]
# ## Instalando e Carregando os Pacotes

# %%
# Carregando apenas os pacotes necessários para tipagem das funções e exibição da versão do Python
from typing import Self, List, Tuple
from platform import python_version

print(f'Versão do Python: {python_version()}')
# Out:
# Versão do Python: 3.11.7

# %%
# Versões dos pacotes usados neste jupyter notebook
# %reload_ext watermark
# %watermark -a "Wallacy Oliveira Pasqualini Nerio"
# Out:
# Author: Wallacy Oliveira Pasqualini Nerio

# %% [markdown]
# ## Classe do algoritmo de Rede Neural escrito em Python "puro"

# %%
# Vamos utilizar programação orientada a objetos (PO) para construir um algoritmo de Rede Neural

class AlgoritmoRedeNeural:
	"""
	Implementa um algoritmo de Rede Neural utilizando Python "puro".
	"""   

	def __init__(self: Self, taxa_aprendizado: float, numero_iteracoes: int) -> None:
		"""
		Método construtor da classe AlgoritmoRedeNeural.

		Args:
			self (Self): Uma instância da classe AlgoritmoRedeNeural.
			taxa_aprendizado (float): A taxa de aprendizado do modelo no treinamento.
			numero_iteracoes (int): O número de iterações que o modelo fará no treinamento.

		Returns:
			None: Não há retorno da função.
		"""

		self.taxa_aprendizado = taxa_aprendizado
		self.numero_iteracoes = numero_iteracoes

		# Inicializa os coeficientes com None, pois é isso que o modelo aprenderá
		self.pesos = None
		self.bias = None

		# Aproximação do número de Euler
		self.euler = (1 + 1 / 1_000_000) ** 1_000_000
	

	def exponencial(self: Self, valor: float) -> float:
		"""
		Calcula o exponencial natural de um número.

		Args:
			self (Self): Uma instância da classe AlgoritmoRedeNeural.
			valor (float): O número que terá seu exponencial natural calculado.

		Returns:
			float: O exponencial natural do número.
		"""

		return self.euler ** valor


	def contagem(self: Self, valores: List[int | float]) -> int:
		"""
		Realiza a contagem de quantos valores há em uma lista.

		Args:
			self (Self): Uma instância da classe AlgoritmoRedeNeural.
			valores (List[int | float]): A lista que terá seus valores contados.

		Returns:
			int: A contagem dos valores da lista.
		"""

		contagem_valores = 0
		for _ in valores:
			contagem_valores += 1

		return contagem_valores


	def sequencia(self: Self, tamanho: int) -> List[int]:
		"""
		Fornece uma lista de números inteiros positivos que vai de 0 até o tamanho desejado.

		Args:
			self (Self): Uma instância da classe AlgoritmoRedeNeural.
			tamanho (int): O tamanho desejado para a lista.

		Returns:
			List[int]: A lista com os números inteiros positivos de 0 até o tamanho desejado.
		"""

		sequencia = []
		contagem = 0
		while contagem < tamanho:
			sequencia += [contagem]
			contagem += 1

		return sequencia


	def maximo(self: Self, *args: float) -> float:
		"""
		Retorna o maior valor.

		Args:
			self (Self): Uma instância da classe AlgoritmoRedeNeural.
			args (float): Os valores entre os quais se deseja retornar o maior.

		Returns:
			float: O maior valor.
		"""

		maior_valor = args[0]

		for v in args:
			if v > maior_valor:
				maior_valor = v

		return maior_valor	


	def minimo(self: Self, *args: float) -> float:
		"""
		Retorna o menor valor.

		Args:
			self (Self): Uma instância da classe AlgoritmoRedeNeural.
			args (float): Os valores entre os quais se deseja retornar o menor.

		Returns:
			float: O menor valor.
		"""

		menor_valor = args[0]

		for v in args:
			if v < menor_valor:
				menor_valor = v

		return menor_valor	


	def somatorio(self: Self, valores: List[List[int | float]]) -> float:
		"""
		Realiza a soma dos valores de uma lista.

		Args:
			self (Self): Uma instância da classe AlgoritmoRedeNeural.
			valores (List[List[int | float]]): A lista que terá seus valores somados.

		Returns:
			float: A soma dos valores da lista.
		"""

		valores_somados = 0
		for v in valores:
			valores_somados += v[0]

		return valores_somados


	def sigmoide(self: Self, previsao: float) -> float:
		"""
		Função de ativação sigmóide para gerar a previsão no formato que pode ser interpretado como probabilidade.
		Ou seja, gera um valor entre 0 e 1 para a classe prevista.

		Args:
			self (Self): Uma instância da classe AlgoritmoRedeNeural.
			previsao (float): A previsão vinda da Rede Neural para a classe prevista.

		Returns:
			float: A previsão após a ativação sigmóide, sendo um valor entre 0 e 1.
		"""

		return 1 / (1 + self.exponencial(-previsao))
	

	def junta_listas(self: Self, lista_1: List[int | float], lista_2: List[int | float]) -> List[Tuple[float]]:
		"""
		Combina duas listas em uma única lista de tuplas, onde cada tupla contém um elemento de cada lista até o comprimento mínimo entre as duas.

		Args:
			self (Self): Uma instância da classe AlgoritmoRedeNeural.
			lista_1 (List[int | float]): A primeira lista unidimensional, a ser combinada com `lista_2`.
			lista_2 (List[int | float]): A segunda lista unidimensional a ser combinada com `lista_1`.

		Returns:
			List[Tuple[float]]: Uma lista de tuplas, onde cada tupla é formada por um par de elementos, um de cada lista. A combinação para quando atinge o comprimento da menor lista.
		"""

		tamanho_lista_1 = self.contagem(lista_1)
		tamanho_lista_2 = self.contagem(lista_2)
		tamanho = self.minimo(tamanho_lista_1, tamanho_lista_2)
		
		# Empacota os elementos até o tamanho mínimo
		listas_concatenadas = [(lista_1[i], lista_2[i]) for i in self.sequencia(tamanho)]
				
		return listas_concatenadas


	def transpoe_matriz(self: Self, matriz: List[List[int | float]]) -> List[List[int | float]]:
		"""
		Calcula a transposta de uma matriz.

		Args:
			matriz (List[List[int | float]]): A matriz que será transposta.

		Returns:
			List[List[int | float]]: A matriz transposta.
		"""
		
		matriz_resultante = [[0 for _ in self.sequencia(self.contagem(matriz))] for _ in self.sequencia(self.contagem(matriz[0]))]
		for linha in self.sequencia(self.contagem(matriz_resultante)):
			for coluna in self.sequencia(self.contagem(matriz_resultante[linha])):
				matriz_resultante[linha][coluna] = matriz[coluna][linha]

		return matriz_resultante


	def multiplica_matrizes(self: Self, matriz_1: List[List[int | float]], matriz_2: List[List[int | float]]) -> List[List[int | float]]:
		"""
		Realiza a multiplicação de duas matrizes.

		Args:
			matriz_1 (List[List[int | float]]): A primeira matriz da multiplicação.
			matriz_2 (List[List[int | float]]): A segunda matriz da multiplicação.

		Returns:
			List[List[int | float]]: A multiplicação das matrizes.
		"""

		matriz_resultante = [[0 for _ in self.sequencia(self.contagem(matriz_2[0]))] for _ in self.sequencia(self.contagem(matriz_1))]
		for linha in self.sequencia(self.contagem(matriz_resultante)):
			for coluna in self.sequencia(self.contagem(matriz_resultante[linha])):
				matriz_resultante[linha][coluna] = self.somatorio([[i * j] for i, j in self.junta_listas(matriz_1[linha], [x[coluna] for x in matriz_2])])

		return matriz_resultante


	def treinamento(self: Self, dados_entrada: List[List[int | float]], dados_saida: List[int | float]) -> None:
		"""
		Realiza o treinamento do modelo de Rede Neural.

		Args:
			self (Self): Uma instância da classe AlgoritmoRedeNeural.
			dados_entrada (List[List[int | float]]): Os dados de entrada da base de treino, ou seja, das variáveis preditoras.
			dados_saida (List[int | float]): Os dados de saída da base de treino, ou seja, da variável alvo.

		Returns:
			None: Não há retorno da função.
		"""

		numero_registros = self.contagem(dados_entrada)
		numero_atributos = self.contagem(dados_entrada[0])

		# Inicializa os coeficientes com zeros
		self.pesos = [[0] for _ in self.sequencia(numero_atributos)]
		self.bias = 0

		print('\nTreinamento iniciado!')

		# Realiza as iterações conforme o número de iterações passado como argumento
		for i in self.sequencia(self.numero_iteracoes):
			print(f'\nTreinamento do modelo na iteração {i + 1}:')


			# A primeira parte do treinamento é o forward pass (passada pra frente)

			# Faz a previsão do modelo
			previsoes = self.multiplica_matrizes(dados_entrada, self.pesos)
			previsoes = [[p[0] + self.bias] for p in previsoes]
			print(f'Previsões antes da função de ativação sigmóide: {"; ".join([f"{p[0]:_.6f}" for p in previsoes[:5]])}'.replace('.', ',').replace('_', '.') + ("; ..." if self.contagem(previsoes) > 5 else ""))

			# Passa a previsão pela função de ativação sigmóide
			previsoes = [[self.sigmoide(p[0])] for p in previsoes]
			print(f'Previsões depois da função de ativação sigmóide: {"; ".join([f"{p[0]:_.6f}" for p in previsoes[:5]])}'.replace('.', ',').replace('_', '.') + ("; ..." if self.contagem(previsoes) > 5 else ""))

			# Calcula os erros do modelo com os dados reais de saída da base de treino
			erros = [[p - ds] for p, ds in self.junta_listas([p[0] for p in previsoes], dados_saida)]
			print(f'Erros do modelo: {"; ".join([f"{e[0]:_.6f}" for e in erros[:5]])}'.replace('.', ',').replace('_', '.') + ("; ..." if self.contagem(erros) > 5 else ""))


			# A segunda parte do treinamento é o backward pass (passada pra trás ou backpropagation)

			# Calcula os gradientes (derivadas da matriz de peso e do bias)
			gradiente_pesos = [[(1 / numero_registros) * r[0]] for r in self.multiplica_matrizes(self.transpoe_matriz(dados_entrada), erros)]
			gradiente_bias = (1 / numero_registros) * self.somatorio(erros)

			# Atualiza os pesos e bias usando o valor das derivadas e a taxa de aprendizado
			self.pesos = [[p[0] - (gp[0] * self.taxa_aprendizado)] for p, gp in self.junta_listas(self.pesos, gradiente_pesos)]
			print('Valores de pesos:')
			for i in self.sequencia(self.minimo(self.contagem(self.pesos), 5)):
				print(f'{i + 1}_ {"; ".join([f"{p:_.6f}" for p in self.pesos[i][:5]])}'.replace('.', ',').replace('_', '.') + ("; ..." if self.contagem(self.pesos[i]) > 5 else ""))

			if self.contagem(self.pesos) > 5:
				print(f'{i + 2}. {"; ".join(["..." for _ in self.pesos[0][:5]])}' + ("; ..." if self.contagem(self.pesos[0]) > 5 else ""))

			self.bias -= gradiente_bias * self.taxa_aprendizado
			print(f'Valor do bias: {self.bias:_.6f}'.replace('.', ',').replace('_', '.'))
		
		print('\nTreinamento concluído!')


	def previsao(self: Self, dados: List[List[int | float]]) -> List[int | float]:
		"""
		Realiza as previsões com os valores de self.pesos e self.bias obtidos no treinamento.

		Args:
			self (Self): Uma instância da classe AlgoritmoRedeNeural.
			dados (List[List[int | float]]): Os dados de entrada utilizados para realizar as previsões.

		Returns:
			List[int | float]: As previsões do modelo.
		"""

		# Faz a previsão do modelo
		previsoes = self.multiplica_matrizes(dados, self.pesos)
		previsoes = [[p[0] + self.bias] for p in previsoes]
		print(f'Previsões antes da função de ativação sigmóide: {"; ".join([f"{p[0]:_.6f}" for p in previsoes[:5]])} {"..." if self.contagem(previsoes) > 5 else ""}'.replace('.', ',').replace('_', '.'))

		# Passa a previsão pela função de ativação sigmóide
		previsoes = [[self.sigmoide(p[0])] for p in previsoes]
		print(f'Previsões depois da função de ativação sigmóide: {"; ".join([f"{p[0]:_.6f}" for p in previsoes[:5]])} {"..." if self.contagem(previsoes) > 5 else ""}'.replace('.', ',').replace('_', '.'))

		# Passa as previsões pelo cut-off
		previsoes = [1 if p[0] > 0.5 else 0 for p in previsoes]
		print(f'Previsões das classes depois de realizar o cut-off: {"; ".join([f"{p:d}" for p in previsoes[:5]])} {"..." if self.contagem(previsoes) > 5 else ""}'.replace('.', ',').replace('_', '.'))

		return previsoes

# %% [markdown]
# ## Dados de Treino e Teste

# %%
# Suponhamos que os dados de entrada representem o número de compras em uma transação comercial
# Temos 2 atributos e 8 registros:
dados_entrada = [ [1, 2.5], [2, 3], [3, 5], [1, 4], [5, 6], [6, 7], [1.5, 2], [4, 5.5] ]
dados_entrada
# Out:
# [[1, 2.5], [2, 3], [3, 5], [1, 4], [5, 6], [6, 7], [1.5, 2], [4, 5.5]]

# %%
# Já os dados de saída representam, por exemplo, se a transação foi ou não suspeita
# Temos 8 registros:
dados_saida = [0, 0, 1, 0, 1, 1, 0, 1]
dados_saida
# Out:
# [0, 0, 1, 0, 1, 1, 0, 1]

# %% [markdown]
# > Dicionário dos dados de saída:
#
# Classe 0: não é transação suspeita.
#
# Classe 1: é transação suspeita.

# %% [markdown]
# > Vamos usar 6 registros para treinar o modelo e 2 para avaliar o modelo depois de treinado.

# %%
# Separa os dados de entrada para o treinamento do modelo
dados_entrada_treino = dados_entrada[:6]
dados_entrada_treino
# Out:
# [[1, 2.5], [2, 3], [3, 5], [1, 4], [5, 6], [6, 7]]

# %%
# Separa os dados de saída para o treinamento do modelo
dados_saida_treino = dados_saida[:6]
dados_saida_treino
# Out:
# [0, 0, 1, 0, 1, 1]

# %% [markdown]
# ## Treinamento do Modelo

# %%
# Define os hiperparâmetros (controlam o processo de treinamento)
taxa_aprendizado = 0.01
numero_iteracoes = 1_000

# %%
# Cria o modelo a partir da classe (ou seja, cria a instância da classe, um objeto)
modelo = AlgoritmoRedeNeural(taxa_aprendizado, numero_iteracoes)

# %%
# Treina o modelo com os dados de treino
modelo.treinamento(dados_entrada_treino, dados_saida_treino)
# Out:
# Treinamento iniciado!
#
# Treinamento do modelo na iteração 1:
# Previsões antes da função de ativação sigmóide: 0,000000; 0,000000; 0,000000; 0,000000; 0,000000; ...
# Previsões depois da função de ativação sigmóide: 0,500000; 0,500000; 0,500000; 0,500000; 0,500000; ...
# Erros do modelo: 0,500000; 0,500000; -0,500000; 0,500000; -0,500000; ...
# Valores de pesos:
# 1. 0,008333
# 2. 0,007083
# Valor do bias: 0,000000
#
# Treinamento do modelo na iteração 2:
# Previsões antes da função de ativação sigmóide: 0,026042; 0,037917; 0,060417; 0,036667; 0,084167; ...
# Previsões depois da função de ativação sigmóide: 0,506510; 0,509478; 0,515100; 0,509166; 0,521029; ...
# Erros do modelo: 0,506510; 0,509478; -0,484900; 0,509166; -0,478971; ...
# Valores de pesos:
# 1. 0,016109
# 2. 0,013405
# Valor do bias: -0,000144
#
# Treinamento do modelo na iteração 3:
# Previsões antes da função de ativação sigmóide: 0,049478; 0,072289; 0,115208; 0,069585; 0,160832; ...
# Previsões depois da função de ativação sigmóide: 0,512367; 0,518064; 0,528770; 0,517389; 0,540122; ...
# Erros do modelo: 0,512367; 0,518064; -0,471230; 0,517389; -0,459878; ...
# Valores de pesos:
# 1. 0,023380
# 2. 0,019036
# Valor do bias: -0,000417
#
# Treinamento do modelo na iteração 4:
# Previsões antes da função de ativação sigmóide: 0,070553; 0,103451; 0,164903; 0,099106; 0,230699; ...
# Previsões depois da função de ativação sigmóide: 0,517631; 0,525840; 0,541133; 0,524756; 0,557420; ...
# Erros do modelo: 0,517631; 0,525840; -0,458867; 0,524756; -0,442580; ...
# Valores de pesos:
# 1. 0,030194
# 2. 0,024043
# Valor do bias: -0,000808
#
# Treinamento do modelo na iteração 5:
# Previsões antes da função de ativação sigmóide: 0,089493; 0,131708; 0,209988; 0,125557; 0,294419; ...
# Previsões depois da função de ativação sigmóide: 0,522358; 0,532880; 0,552305; 0,531348; 0,573078; ...
# Erros do modelo: 0,522358; 0,532880; -0,447695; 0,531348; -0,426922; ...
# Valores de pesos:
# 1. 0,036595
# 2. 0,028486
# Valor do bias: -0,001305
#
# Treinamento do modelo na iteração 6:
# Previsões antes da função de ativação sigmóide: 0,106505; 0,157343; 0,250910; 0,149234; 0,352587; ...
# Previsões depois da função de ativação sigmóide: 0,526601; 0,539255; 0,562401; 0,537239; 0,587245; ...
# Erros do modelo: 0,526601; 0,539255; -0,437599; 0,537239; -0,412755; ...
# Valores de pesos:
# 1. 0,042623
# 2. 0,032421
# Valor do bias: -0,001898
#
# Treinamento do modelo na iteração 7:
# Previsões antes da função de ativação sigmóide: 0,121777; 0,180610; 0,288075; 0,170408; 0,405741; ...
# Previsões depois da função de ativação sigmóide: 0,530407; 0,545030; 0,571525; 0,542499; 0,600066; ...
# Erros do modelo: 0,530407; 0,545030; -0,428475; 0,542499; -0,399934; ...
# Valores de pesos:
# 1. 0,048314
# 2. 0,035896
# Valor do bias: -0,002577
#
# Treinamento do modelo na iteração 8:
# Previsões antes da função de ativação sigmóide: 0,135478; 0,201739; 0,321846; 0,189322; 0,454370; ...
# Previsões depois da função de ativação sigmóide: 0,533818; 0,550264; 0,579774; 0,547190; 0,611678; ...
# Erros do modelo: 0,533818; 0,550264; -0,420226; 0,547190; -0,388322; ...
# Valores de pesos:
# 1. 0,053700
# 2. 0,038957
# Valor do bias: -0,003334
#
# Treinamento do modelo na iteração 9:
# Previsões antes da função de ativação sigmóide: 0,147759; 0,220938; 0,352553; 0,206196; 0,498911; ...
# Previsões depois da função de ativação sigmóide: 0,536873; 0,555011; 0,587237; 0,551367; 0,622203; ...
# Erros do modelo: 0,536873; 0,555011; -0,412763; 0,551367; -0,377797; ...
# Valores de pesos:
# 1. 0,058811
# 2. 0,041644
# Valor do bias: -0,004162
#
# Treinamento do modelo na iteração 10:
# Previsões antes da função de ativação sigmóide: 0,158759; 0,238392; 0,380491; 0,221225; 0,539757; ...
# Previsões depois da função de ativação sigmóide: 0,539607; 0,559317; 0,593992; 0,555082; 0,631756; ...
# Erros do modelo: 0,539607; 0,559317; -0,406008; 0,555082; -0,368244; ...
# Valores de pesos:
# 1. 0,063673
# 2. 0,043992
# Valor do bias: -0,005053
#
# Treinamento do modelo na iteração 11:
# Previsões antes da função de ativação sigmóide: 0,168599; 0,254268; 0,405924; 0,234587; 0,577262; ...
# Previsões depois da função de ativação sigmóide: 0,542050; 0,563227; 0,600110; 0,558379; 0,640437; ...
# Erros do modelo: 0,542050; 0,563227; -0,399890; 0,558379; -0,359563; ...
# Valores de pesos:
# 1. 0,068309
# 2. 0,046033
# Valor do bias: -0,006001
#
# Treinamento do modelo na iteração 12:
# Previsões antes da função de ativação sigmóide: 0,177390; 0,268715; 0,429089; 0,246438; 0,611740; ...
# Previsões depois da função de ativação sigmóide: 0,544231; 0,566777; 0,605656; 0,561300; 0,648337; ...
# Erros do modelo: 0,544231; 0,566777; -0,394344; 0,561300; -0,351663; ...
# Valores de pesos:
# 1. 0,072740
# 2. 0,047796
# Valor do bias: -0,007001
#
# Treinamento do modelo na iteração 13:
# Previsões antes da função de ativação sigmóide: 0,185228; 0,281866; 0,450198; 0,256922; 0,643474; ...
# Previsões depois da função de ativação sigmóide: 0,546175; 0,570004; 0,610686; 0,563880; 0,655538; ...
# Erros do modelo: 0,546175; 0,570004; -0,389314; 0,563880; -0,344462; ...
# Valores de pesos:
# 1. 0,076985
# 2. 0,049307
# Valor do bias: -0,008049
#
# Treinamento do modelo na iteração 14:
# Previsões antes da função de ativação sigmóide: 0,192204; 0,293842; 0,469442; 0,266165; 0,672718; ...
# Previsões depois da função de ativação sigmóide: 0,547904; 0,572936; 0,615252; 0,566151; 0,662111; ...
# Erros do modelo: 0,547904; 0,572936; -0,384748; 0,566151; -0,337889; ...
# Valores de pesos:
# 1. 0,081060
# 2. 0,050590
# Valor do bias: -0,009139
#
# Treinamento do modelo na iteração 15:
# Previsões antes da função de ativação sigmóide: 0,198396; 0,304751; 0,486990; 0,274280; 0,699700; ...
# Previsões depois da função de ativação sigmóide: 0,549437; 0,575603; 0,619397; 0,568143; 0,668121; ...
# Erros do modelo: 0,549437; 0,575603; -0,380603; 0,568143; -0,331879; ...
# Valores de pesos:
# 1. 0,084981
# 2. 0,051665
# Valor do bias: -0,010268
#
# Treinamento do modelo na iteração 16:
# Previsões antes da função de ativação sigmóide: 0,203874; 0,314688; 0,502998; 0,281371; 0,724624; ...
# Previsões depois da função de ativação sigmóide: 0,550793; 0,578029; 0,623164; 0,569882; 0,673624; ...
# Erros do modelo: 0,550793; 0,578029; -0,376836; 0,569882; -0,326376; ...
# Valores de pesos:
# 1. 0,088761
# 2. 0,052550
# Valor do bias: -0,011432
#
# Treinamento do modelo na iteração 17:
# Previsões antes da função de ativação sigmóide: 0,208705; 0,323741; 0,517602; 0,287530; 0,747675; ...
# Previsões depois da função de ativação sigmóide: 0,551988; 0,580236; 0,626587; 0,571391; 0,678672; ...
# Erros do modelo: 0,551988; 0,580236; -0,373413; 0,571391; -0,321328; ...
# Valores de pesos:
# 1. 0,092413
# 2. 0,053264
# Valor do bias: -0,012628
#
# Treinamento do modelo na iteração 18:
# Previsões antes da função de ativação sigmóide: 0,212944; 0,331988; 0,530928; 0,292839; 0,769017; ...
# Previsões depois da função de ativação sigmóide: 0,553036; 0,582243; 0,629699; 0,572691; 0,683308; ...
# Erros do modelo: 0,553036; 0,582243; -0,370301; 0,572691; -0,316692; ...
# Valores de pesos:
# 1. 0,095947
# 2. 0,053820
# Valor do bias: -0,013853
#
# Treinamento do modelo na iteração 19:
# Previsões antes da função de ativação sigmóide: 0,216644; 0,339501; 0,543087; 0,297374; 0,788801; ...
# Previsões depois da função de ativação sigmóide: 0,553950; 0,584069; 0,632530; 0,573800; 0,687574; ...
# Erros do modelo: 0,553950; 0,584069; -0,367470; 0,573800; -0,312426; ...
# Valores de pesos:
# 1. 0,099373
# 2. 0,054233
# Valor do bias: -0,015104
#
# Treinamento do modelo na iteração 20:
# Previsões antes da função de ativação sigmóide: 0,219852; 0,346342; 0,554181; 0,301202; 0,807160; ...
# Previsões depois da função de ativação sigmóide: 0,554743; 0,585730; 0,635105; 0,574736; 0,691504; ...
# Erros do modelo: 0,554743; 0,585730; -0,364895; 0,574736; -0,308496; ...
# Valores de pesos:
# 1. 0,102701
# 2. 0,054516
# Valor do bias: -0,016379
#
# Treinamento do modelo na iteração 21:
# Previsões antes da função de ativação sigmóide: 0,222611; 0,352569; 0,564302; 0,304385; 0,824219; ...
# Previsões depois da função de ativação sigmóide: 0,555424; 0,587240; 0,637447; 0,575514; 0,695131; ...
# Erros do modelo: 0,555424; 0,587240; -0,362553; 0,575514; -0,304869; ...
# Valores de pesos:
# 1. 0,105938
# 2. 0,054679
# Valor do bias: -0,017676
#
# Treinamento do modelo na iteração 22:
# Previsões antes da função de ativação sigmóide: 0,224959; 0,358236; 0,573532; 0,306977; 0,840086; ...
# Previsões depois da função de ativação sigmóide: 0,556004; 0,588613; 0,639578; 0,576147; 0,698483; ...
# Erros do modelo: 0,556004; 0,588613; -0,360422; 0,576147; -0,301517; ...
# Valores de pesos:
# 1. 0,109092
# 2. 0,054733
# Valor do bias: -0,018993
#
# Treinamento do modelo na iteração 23:
# Previsões antes da função de ativação sigmóide: 0,226931; 0,363389; 0,581946; 0,309030; 0,854862; ...
# Previsões depois da função de ativação sigmóide: 0,556491; 0,589861; 0,641515; 0,576649; 0,701586; ...
# Erros do modelo: 0,556491; 0,589861; -0,358485; 0,576649; -0,298414; ...
# Valores de pesos:
# 1. 0,112169
# 2. 0,054687
# Valor do bias: -0,020327
#
# Treinamento do modelo na iteração 24:
# Previsões antes da função de ativação sigmóide: 0,228559; 0,368071; 0,589614; 0,310590; 0,868639; ...
# Previsões depois da função de ativação sigmóide: 0,556892; 0,590993; 0,643277; 0,577029; 0,704462; ...
# Erros do modelo: 0,556892; 0,590993; -0,356723; 0,577029; -0,295538; ...
# Valores de pesos:
# 1. 0,115176
# 2. 0,054550
# Valor do bias: -0,021679
#
# Treinamento do modelo na iteração 25:
# Previsões antes da função de ativação sigmóide: 0,229872; 0,372322; 0,596597; 0,311696; 0,881498; ...
# Previsões depois da função de ativação sigmóide: 0,557216; 0,592020; 0,644877; 0,577299; 0,707133; ...
# Erros do modelo: 0,557216; 0,592020; -0,355123; 0,577299; -0,292867; ...
# Valores de pesos:
# 1. 0,118117
# 2. 0,054329
# Valor do bias: -0,023044
#
# Treinamento do modelo na iteração 26:
# Previsões antes da função de ativação sigmóide: 0,230895; 0,376177; 0,602952; 0,312389; 0,893516; ...
# Previsões depois da função de ativação sigmóide: 0,557469; 0,592951; 0,646331; 0,577468; 0,709615; ...
# Erros do modelo: 0,557469; 0,592951; -0,353669; 0,577468; -0,290385; ...
# Valores de pesos:
# 1. 0,120999
# 2. 0,054031
# Valor do bias: -0,024424
#
# Treinamento do modelo na iteração 27:
# Previsões antes da função de ativação sigmóide: 0,231654; 0,379669; 0,608731; 0,312701; 0,904761; ...
# Previsões depois da função de ativação sigmóide: 0,557656; 0,593793; 0,647651; 0,577544; 0,711927; ...
# Erros do modelo: 0,557656; 0,593793; -0,352349; 0,577544; -0,288073; ...
# Valores de pesos:
# 1. 0,123826
# 2. 0,053664
# Valor do bias: -0,025816
#
# Treinamento do modelo na iteração 28:
# Previsões antes da função de ativação sigmóide: 0,232169; 0,382827; 0,613979; 0,312664; 0,915294; ...
# Previsões depois da função de ativação sigmóide: 0,557783; 0,594555; 0,648848; 0,577535; 0,714082; ...
# Erros do modelo: 0,557783; 0,594555; -0,351152; 0,577535; -0,285918; ...
# Valores de pesos:
# 1. 0,126601
# 2. 0,053231
# Valor do bias: -0,027218
#
# Treinamento do modelo na iteração 29:
# Previsões antes da função de ativação sigmóide: 0,232461; 0,385678; 0,618741; 0,312308; 0,925175; ...
# Previsões depois da função de ativação sigmóide: 0,557855; 0,595242; 0,649932; 0,577448; 0,716095; ...
# Erros do modelo: 0,557855; 0,595242; -0,350068; 0,577448; -0,283905; ...
# Valores de pesos:
# 1. 0,129329
# 2. 0,052740
# Valor do bias: -0,028631
#
# Treinamento do modelo na iteração 30:
# Previsões antes da função de ativação sigmóide: 0,232548; 0,388247; 0,623056; 0,311658; 0,934454; ...
# Previsões depois da função de ativação sigmóide: 0,557876; 0,595861; 0,650913; 0,577290; 0,717978; ...
# Erros do modelo: 0,557876; 0,595861; -0,349087; 0,577290; -0,282022; ...
# Valores de pesos:
# 1. 0,132013
# 2. 0,052195
# Valor do bias: -0,030054
#
# Treinamento do modelo na iteração 31:
# Previsões antes da função de ativação sigmóide: 0,232446; 0,390556; 0,626959; 0,310738; 0,943179; ...
# Previsões depois da função de ativação sigmóide: 0,557851; 0,596417; 0,651799; 0,577065; 0,719741; ...
# Erros do modelo: 0,557851; 0,596417; -0,348201; 0,577065; -0,280259; ...
# Valores de pesos:
# 1. 0,134656
# 2. 0,051599
# Valor do bias: -0,031484
#
# Treinamento do modelo na iteração 32:
# Previsões antes da função de ativação sigmóide: 0,232171; 0,392627; 0,630483; 0,309570; 0,951395; ...
# Previsões depois da função de ativação sigmóide: 0,557783; 0,596915; 0,652599; 0,576780; 0,721396; ...
# Erros do modelo: 0,557783; 0,596915; -0,347401; 0,576780; -0,278604; ...
# Valores de pesos:
# 1. 0,137262
# 2. 0,050959
# Valor do bias: -0,032922
#
# Treinamento do modelo na iteração 33:
# Previsões antes da função de ativação sigmóide: 0,231737; 0,394478; 0,633658; 0,308175; 0,959141; ...
# Previsões depois da função de ativação sigmóide: 0,557676; 0,597360; 0,653318; 0,576440; 0,722950; ...
# Erros do modelo: 0,557676; 0,597360; -0,346682; 0,576440; -0,277050; ...
# Valores de pesos:
# 1. 0,139832
# 2. 0,050276
# Valor do bias: -0,034366
#
# Treinamento do modelo na iteração 34:
# Previsões antes da função de ativação sigmóide: 0,231157; 0,396127; 0,636512; 0,306571; 0,966453; ...
# Previsões depois da função de ativação sigmóide: 0,557533; 0,597757; 0,653965; 0,576048; 0,724412; ...
# Erros do modelo: 0,557533; 0,597757; -0,346035; 0,576048; -0,275588; ...
# Valores de pesos:
# 1. 0,142370
# 2. 0,049555
# Valor do bias: -0,035817
#
# Treinamento do modelo na iteração 35:
# Previsões antes da função de ativação sigmóide: 0,230441; 0,397589; 0,639070; 0,304774; 0,973366; ...
# Previsões depois da função de ativação sigmóide: 0,557357; 0,598108; 0,654543; 0,575609; 0,725790; ...
# Erros do modelo: 0,557357; 0,598108; -0,345457; 0,575609; -0,274210; ...
# Valores de pesos:
# 1. 0,144878
# 2. 0,048799
# Valor do bias: -0,037273
#
# Treinamento do modelo na iteração 36:
# Previsões antes da função de ativação sigmóide: 0,229603; 0,398880; 0,641356; 0,302801; 0,979911; ...
# Previsões depois da função de ativação sigmóide: 0,557150; 0,598418; 0,655060; 0,575127; 0,727090; ...
# Erros do modelo: 0,557150; 0,598418; -0,344940; 0,575127; -0,272910; ...
# Valores de pesos:
# 1. 0,147357
# 2. 0,048011
# Valor do bias: -0,038734
#
# Treinamento do modelo na iteração 37:
# Previsões antes da função de ativação sigmóide: 0,228650; 0,400012; 0,643391; 0,300666; 0,986115; ...
# Previsões depois da função de ativação sigmóide: 0,556915; 0,598691; 0,655519; 0,574605; 0,728320; ...
# Erros do modelo: 0,556915; 0,598691; -0,344481; 0,574605; -0,271680; ...
# Valores de pesos:
# 1. 0,149810
# 2. 0,047193
# Valor do bias: -0,040200
#
# Treinamento do modelo na iteração 38:
# Previsões antes da função de ativação sigmóide: 0,227592; 0,400998; 0,645194; 0,298381; 0,992006; ...
# Previsões depois da função de ativação sigmóide: 0,556654; 0,598927; 0,655926; 0,574047; 0,729484; ...
# Erros do modelo: 0,556654; 0,598927; -0,344074; 0,574047; -0,270516; ...
# Valores de pesos:
# 1. 0,152238
# 2. 0,046348
# Valor do bias: -0,041669
#
# Treinamento do modelo na iteração 39:
# Previsões antes da função de ativação sigmóide: 0,226438; 0,401850; 0,646783; 0,295959; 0,997606; ...
# Previsões depois da função de ativação sigmóide: 0,556369; 0,599132; 0,656285; 0,573454; 0,730588; ...
# Erros do modelo: 0,556369; 0,599132; -0,343715; 0,573454; -0,269412; ...
# Valores de pesos:
# 1. 0,154643
# 2. 0,045478
# Valor do bias: -0,043142
#
# Treinamento do modelo na iteração 40:
# Previsões antes da função de ativação sigmóide: 0,225195; 0,402577; 0,648175; 0,293412; 1,002939; ...
# Previsões depois da função de ativação sigmóide: 0,556062; 0,599307; 0,656599; 0,572831; 0,731636; ...
# Erros do modelo: 0,556062; 0,599307; -0,343401; 0,572831; -0,268364; ...
# Valores de pesos:
# 1. 0,157026
# 2. 0,044585
# Valor do bias: -0,044618
#
# Treinamento do modelo na iteração 41:
# Previsões antes da função de ativação sigmóide: 0,223871; 0,403190; 0,649386; 0,290748; 1,008023; ...
# Previsões depois da função de ativação sigmóide: 0,555735; 0,599454; 0,656872; 0,572179; 0,732633; ...
# Erros do modelo: 0,555735; 0,599454; -0,343128; 0,572179; -0,267367; ...
# Valores de pesos:
# 1. 0,159390
# 2. 0,043671
# Valor do bias: -0,046096
#
# Treinamento do modelo na iteração 42:
# Previsões antes da função de ativação sigmóide: 0,222471; 0,403697; 0,650429; 0,287978; 1,012879; ...
# Previsões depois da função de ativação sigmóide: 0,555390; 0,599575; 0,657107; 0,571501; 0,733583; ...
# Erros do modelo: 0,555390; 0,599575; -0,342893; 0,571501; -0,266417; ...
# Valores de pesos:
# 1. 0,161734
# 2. 0,042738
# Valor do bias: -0,047577
#
# Treinamento do modelo na iteração 43:
# Previsões antes da função de ativação sigmóide: 0,221003; 0,404106; 0,651317; 0,285111; 1,017524; ...
# Previsões depois da função de ativação sigmóide: 0,555027; 0,599674; 0,657307; 0,570799; 0,734490; ...
# Erros do modelo: 0,555027; 0,599674; -0,342693; 0,570799; -0,265510; ...
# Valores de pesos:
# 1. 0,164061
# 2. 0,041788
# Valor do bias: -0,049060
#
# Treinamento do modelo na iteração 44:
# Previsões antes da função de ativação sigmóide: 0,219471; 0,404426; 0,652063; 0,282153; 1,021972; ...
# Previsões depois da função de ativação sigmóide: 0,554649; 0,599751; 0,657475; 0,570074; 0,735357; ...
# Erros do modelo: 0,554649; 0,599751; -0,342525; 0,570074; -0,264643; ...
# Valores de pesos:
# 1. 0,166371
# 2. 0,040822
# Valor do bias: -0,050544
#
# Treinamento do modelo na iteração 45:
# Previsões antes da função de ativação sigmóide: 0,217881; 0,404662; 0,652677; 0,279114; 1,026240; ...
# Previsões depois da função de ativação sigmóide: 0,554256; 0,599807; 0,657613; 0,569329; 0,736186; ...
# Erros do modelo: 0,554256; 0,599807; -0,342387; 0,569329; -0,263814; ...
# Valores de pesos:
# 1. 0,168665
# 2. 0,039841
# Valor do bias: -0,052031
#
# Treinamento do modelo na iteração 46:
# Previsões antes da função de ativação sigmóide: 0,216237; 0,404822; 0,653169; 0,275999; 1,030340; ...
# Previsões depois da função de ativação sigmóide: 0,553850; 0,599846; 0,657724; 0,568565; 0,736982; ...
# Erros do modelo: 0,553850; 0,599846; -0,342276; 0,568565; -0,263018; ...
# Valores de pesos:
# 1. 0,170944
# 2. 0,038847
# Valor do bias: -0,053518
#
# Treinamento do modelo na iteração 47:
# Previsões antes da função de ativação sigmóide: 0,214544; 0,404912; 0,653550; 0,272814; 1,034285; ...
# Previsões depois da função de ativação sigmóide: 0,553431; 0,599867; 0,657810; 0,567784; 0,737746; ...
# Erros do modelo: 0,553431; 0,599867; -0,342190; 0,567784; -0,262254; ...
# Valores de pesos:
# 1. 0,173210
# 2. 0,037841
# Valor do bias: -0,055006
#
# Treinamento do modelo na iteração 48:
# Previsões antes da função de ativação sigmóide: 0,212805; 0,404935; 0,653826; 0,269567; 1,038086; ...
# Previsões depois da função de ativação sigmóide: 0,553001; 0,599873; 0,657872; 0,566986; 0,738481; ...
# Erros do modelo: 0,553001; 0,599873; -0,342128; 0,566986; -0,261519; ...
# Valores de pesos:
# 1. 0,175462
# 2. 0,036823
# Valor do bias: -0,056495
#
# Treinamento do modelo na iteração 49:
# Previsões antes da função de ativação sigmóide: 0,211026; 0,404899; 0,654008; 0,266261; 1,041755; ...
# Previsões depois da função de ativação sigmóide: 0,552561; 0,599864; 0,657913; 0,566175; 0,739188; ...
# Erros do modelo: 0,552561; 0,599864; -0,342087; 0,566175; -0,260812; ...
# Valores de pesos:
# 1. 0,177702
# 2. 0,035796
# Valor do bias: -0,057984
#
# Treinamento do modelo na iteração 50:
# Previsões antes da função de ativação sigmóide: 0,209208; 0,404807; 0,654101; 0,262902; 1,045301; ...
# Previsões depois da função de ativação sigmóide: 0,552112; 0,599842; 0,657934; 0,565349; 0,739871; ...
# Erros do modelo: 0,552112; 0,599842; -0,342066; 0,565349; -0,260129; ...
# Valores de pesos:
# 1. 0,179930
# 2. 0,034760
# Valor do bias: -0,059474
#
# Treinamento do modelo na iteração 51:
# Previsões antes da função de ativação sigmóide: 0,207355; 0,404664; 0,654113; 0,259494; 1,048732; ...
# Previsões depois da função de ativação sigmóide: 0,551654; 0,599808; 0,657937; 0,564512; 0,740531; ...
# Erros do modelo: 0,551654; 0,599808; -0,342063; 0,564512; -0,259469; ...
# Valores de pesos:
# 1. 0,182146
# 2. 0,033715
# Valor do bias: -0,060964
#
# Treinamento do modelo na iteração 52:
# Previsões antes da função de ativação sigmóide: 0,205470; 0,404474; 0,654050; 0,256042; 1,052058; ...
# Previsões depois da função de ativação sigmóide: 0,551187; 0,599762; 0,657923; 0,563663; 0,741170; ...
# Erros do modelo: 0,551187; 0,599762; -0,342077; 0,563663; -0,258830; ...
# Valores de pesos:
# 1. 0,184353
# 2. 0,032663
# Valor do bias: -0,062454
#
# Treinamento do modelo na iteração 53:
# Previsões antes da função de ativação sigmóide: 0,203556; 0,404240; 0,653918; 0,252550; 1,055286; ...
# Previsões depois da função de ativação sigmóide: 0,550714; 0,599706; 0,657893; 0,562804; 0,741789; ...
# Erros do modelo: 0,550714; 0,599706; -0,342107; 0,562804; -0,258211; ...
# Valores de pesos:
# 1. 0,186549
# 2. 0,031604
# Valor do bias: -0,063945
#
# Treinamento do modelo na iteração 54:
# Previsões antes da função de ativação sigmóide: 0,201615; 0,403965; 0,653722; 0,249021; 1,058424; ...
# Previsões depois da função de ativação sigmóide: 0,550234; 0,599640; 0,657849; 0,561935; 0,742389; ...
# Erros do modelo: 0,550234; 0,599640; -0,342151; 0,561935; -0,257611; ...
# Valores de pesos:
# 1. 0,188735
# 2. 0,030539
# Valor do bias: -0,065434
#
# Treinamento do modelo na iteração 55:
# Previsões antes da função de ativação sigmóide: 0,199649; 0,403654; 0,653468; 0,245458; 1,061477; ...
# Previsões depois da função de ativação sigmóide: 0,549747; 0,599565; 0,657791; 0,561058; 0,742973; ...
# Erros do modelo: 0,549747; 0,599565; -0,342209; 0,561058; -0,257027; ...
# Valores de pesos:
# 1. 0,190912
# 2. 0,029469
# Valor do bias: -0,066924
#
# Treinamento do modelo na iteração 56:
# Previsões antes da função de ativação sigmóide: 0,197661; 0,403308; 0,653159; 0,241865; 1,064453; ...
# Previsões depois da função de ativação sigmóide: 0,549255; 0,599482; 0,657722; 0,560173; 0,743540; ...
# Erros do modelo: 0,549255; 0,599482; -0,342278; 0,560173; -0,256460; ...
# Valores de pesos:
# 1. 0,193081
# 2. 0,028394
# Valor do bias: -0,068413
#
# Treinamento do modelo na iteração 57:
# Previsões antes da função de ativação sigmóide: 0,195653; 0,402931; 0,652800; 0,238244; 1,067356; ...
# Previsões depois da função de ativação sigmóide: 0,548758; 0,599392; 0,657641; 0,559281; 0,744094; ...
# Erros do modelo: 0,548758; 0,599392; -0,342359; 0,559281; -0,255906; ...
# Valores de pesos:
# 1. 0,195241
# 2. 0,027315
# Valor do bias: -0,069902
#
# Treinamento do modelo na iteração 58:
# Previsões antes da função de ativação sigmóide: 0,193626; 0,402525; 0,652395; 0,234599; 1,070192; ...
# Previsões depois da função de ativação sigmóide: 0,548256; 0,599294; 0,657550; 0,558382; 0,744633; ...
# Erros do modelo: 0,548256; 0,599294; -0,342450; 0,558382; -0,255367; ...
# Valores de pesos:
# 1. 0,197393
# 2. 0,026232
# Valor do bias: -0,071389
#
# Treinamento do modelo na iteração 59:
# Previsões antes da função de ativação sigmóide: 0,191583; 0,402092; 0,651948; 0,230930; 1,072966; ...
# Previsões depois da função de ativação sigmóide: 0,547750; 0,599190; 0,657449; 0,557477; 0,745161; ...
# Erros do modelo: 0,547750; 0,599190; -0,342551; 0,557477; -0,254839; ...
# Valores de pesos:
# 1. 0,199538
# 2. 0,025145
# Valor do bias: -0,072877
#
# Treinamento do modelo na iteração 60:
# Previsões antes da função de ativação sigmóide: 0,189524; 0,401634; 0,651462; 0,227242; 1,075683; ...
# Previsões depois da função de ativação sigmóide: 0,547240; 0,599080; 0,657340; 0,556567; 0,745676; ...
# Erros do modelo: 0,547240; 0,599080; -0,342660; 0,556567; -0,254324; ...
# Valores de pesos:
# 1. 0,201675
# 2. 0,024056
# Valor do bias: -0,074363
#
# Treinamento do modelo na iteração 61:
# Previsões antes da função de ativação sigmóide: 0,187451; 0,401154; 0,650940; 0,223535; 1,078345; ...
# Previsões depois da função de ativação sigmóide: 0,546726; 0,598965; 0,657222; 0,555652; 0,746181; ...
# Erros do modelo: 0,546726; 0,598965; -0,342778; 0,555652; -0,253819; ...
# Valores de pesos:
# 1. 0,203805
# 2. 0,022964
# Valor do bias: -0,075848
#
# Treinamento do modelo na iteração 62:
# Previsões antes da função de ativação sigmóide: 0,185366; 0,400653; 0,650385; 0,219812; 1,080958; ...
# Previsões depois da função de ativação sigmóide: 0,546209; 0,598844; 0,657097; 0,554733; 0,746675; ...
# Erros do modelo: 0,546209; 0,598844; -0,342903; 0,554733; -0,253325; ...
# Valores de pesos:
# 1. 0,205928
# 2. 0,021870
# Valor do bias: -0,077333
#
# Treinamento do modelo na iteração 63:
# Previsões antes da função de ativação sigmóide: 0,183270; 0,400132; 0,649800; 0,216074; 1,083525; ...
# Previsões depois da função de ativação sigmóide: 0,545690; 0,598719; 0,656965; 0,553809; 0,747160; ...
# Erros do modelo: 0,545690; 0,598719; -0,343035; 0,553809; -0,252840; ...
# Valores de pesos:
# 1. 0,208044
# 2. 0,020774
# Valor do bias: -0,078816
#
# Treinamento do modelo na iteração 64:
# Previsões antes da função de ativação sigmóide: 0,181163; 0,399594; 0,649186; 0,212324; 1,086049; ...
# Previsões depois da função de ativação sigmóide: 0,545167; 0,598590; 0,656827; 0,552882; 0,747637; ...
# Erros do modelo: 0,545167; 0,598590; -0,343173; 0,552882; -0,252363; ...
# Valores de pesos:
# 1. 0,210155
# 2. 0,019676
# Valor do bias: -0,080299
#
# Treinamento do modelo na iteração 65:
# Previsões antes da função de ativação sigmóide: 0,179047; 0,399040; 0,648548; 0,208562; 1,088534; ...
# Previsões depois da função de ativação sigmóide: 0,544643; 0,598457; 0,656683; 0,551952; 0,748105; ...
# Erros do modelo: 0,544643; 0,598457; -0,343317; 0,551952; -0,251895; ...
# Valores de pesos:
# 1. 0,212259
# 2. 0,018578
# Valor do bias: -0,081780
#
# Treinamento do modelo na iteração 66:
# Previsões antes da função de ativação sigmóide: 0,176923; 0,398471; 0,647885; 0,204790; 1,090981; ...
# Previsões depois da função de ativação sigmóide: 0,544116; 0,598320; 0,656534; 0,551019; 0,748566; ...
# Erros do modelo: 0,544116; 0,598320; -0,343466; 0,551019; -0,251434; ...
# Valores de pesos:
# 1. 0,214357
# 2. 0,017478
# Valor do bias: -0,083260
#
# Treinamento do modelo na iteração 67:
# Previsões antes da função de ativação sigmóide: 0,174792; 0,397888; 0,647202; 0,201010; 1,093394; ...
# Previsões depois da função de ativação sigmóide: 0,543587; 0,598180; 0,656379; 0,550084; 0,749020; ...
# Erros do modelo: 0,543587; 0,598180; -0,343621; 0,550084; -0,250980; ...
# Valores de pesos:
# 1. 0,216449
# 2. 0,016378
# Valor do bias: -0,084739
#
# Treinamento do modelo na iteração 68:
# Previsões antes da função de ativação sigmóide: 0,172655; 0,397293; 0,646498; 0,197222; 1,095775; ...
# Previsões depois da função de ativação sigmóide: 0,543057; 0,598037; 0,656221; 0,549146; 0,749467; ...
# Erros do modelo: 0,543057; 0,598037; -0,343779; 0,549146; -0,250533; ...
# Valores de pesos:
# 1. 0,218536
# 2. 0,015277
# Valor do bias: -0,086216
#
# Treinamento do modelo na iteração 69:
# Previsões antes da função de ativação sigmóide: 0,170512; 0,396687; 0,645777; 0,193427; 1,098126; ...
# Previsões depois da função de ativação sigmóide: 0,542525; 0,597891; 0,656058; 0,548207; 0,749909; ...
# Erros do modelo: 0,542525; 0,597891; -0,343942; 0,548207; -0,250091; ...
# Valores de pesos:
# 1. 0,220617
# 2. 0,014176
# Valor do bias: -0,087693
#
# Treinamento do modelo na iteração 70:
# Previsões antes da função de ativação sigmóide: 0,168364; 0,396070; 0,645039; 0,189628; 1,100449; ...
# Previsões depois da função de ativação sigmóide: 0,541992; 0,597743; 0,655892; 0,547265; 0,750344; ...
# Erros do modelo: 0,541992; 0,597743; -0,344108; 0,547265; -0,249656; ...
# Valores de pesos:
# 1. 0,222693
# 2. 0,013075
# Valor do bias: -0,089168
#
# Treinamento do modelo na iteração 71:
# Previsões antes da função de ativação sigmóide: 0,166212; 0,395443; 0,644286; 0,185824; 1,102747; ...
# Previsões depois da função de ativação sigmóide: 0,541458; 0,597592; 0,655722; 0,546323; 0,750774; ...
# Erros do modelo: 0,541458; 0,597592; -0,344278; 0,546323; -0,249226; ...
# Valores de pesos:
# 1. 0,224764
# 2. 0,011973
# Valor do bias: -0,090641
#
# Treinamento do modelo na iteração 72:
# Previsões antes da função de ativação sigmóide: 0,164057; 0,394808; 0,643519; 0,182017; 1,105021; ...
# Previsões depois da função de ativação sigmóide: 0,540922; 0,597440; 0,655548; 0,545379; 0,751200; ...
# Erros do modelo: 0,540922; 0,597440; -0,344452; 0,545379; -0,248800; ...
# Valores de pesos:
# 1. 0,226830
# 2. 0,010873
# Valor do bias: -0,092113
#
# Treinamento do modelo na iteração 73:
# Previsões antes da função de ativação sigmóide: 0,161898; 0,394165; 0,642740; 0,178207; 1,107273; ...
# Previsões depois da função de ativação sigmóide: 0,540386; 0,597285; 0,655373; 0,544434; 0,751620; ...
# Erros do modelo: 0,540386; 0,597285; -0,344627; 0,544434; -0,248380; ...
# Valores de pesos:
# 1. 0,228891
# 2. 0,009772
# Valor do bias: -0,093584
#
# Treinamento do modelo na iteração 74:
# Previsões antes da função de ativação sigmóide: 0,159737; 0,393515; 0,641950; 0,174395; 1,109504; ...
# Previsões depois da função de ativação sigmóide: 0,539850; 0,597128; 0,655194; 0,543489; 0,752037; ...
# Erros do modelo: 0,539850; 0,597128; -0,344806; 0,543489; -0,247963; ...
# Valores de pesos:
# 1. 0,230947
# 2. 0,008672
# Valor do bias: -0,095053
#
# Treinamento do modelo na iteração 75:
# Previsões antes da função de ativação sigmóide: 0,157574; 0,392858; 0,641149; 0,170583; 1,111716; ...
# Previsões depois da função de ativação sigmóide: 0,539312; 0,596970; 0,655013; 0,542543; 0,752449; ...
# Erros do modelo: 0,539312; 0,596970; -0,344987; 0,542543; -0,247551; ...
# Valores de pesos:
# 1. 0,232999
# 2. 0,007573
# Valor do bias: -0,096521
#
# Treinamento do modelo na iteração 76:
# Previsões antes da função de ativação sigmóide: 0,155410; 0,392195; 0,640339; 0,166769; 1,113909; ...
# Previsões depois da função de ativação sigmóide: 0,538774; 0,596811; 0,654830; 0,541596; 0,752857; ...
# Erros do modelo: 0,538774; 0,596811; -0,345170; 0,541596; -0,247143; ...
# Valores de pesos:
# 1. 0,235045
# 2. 0,006474
# Valor do bias: -0,097987
#
# Treinamento do modelo na iteração 77:
# Previsões antes da função de ativação sigmóide: 0,153244; 0,391527; 0,639521; 0,162956; 1,116086; ...
# Previsões depois da função de ativação sigmóide: 0,538236; 0,596650; 0,654645; 0,540649; 0,753262; ...
# Erros do modelo: 0,538236; 0,596650; -0,345355; 0,540649; -0,246738; ...
# Valores de pesos:
# 1. 0,237088
# 2. 0,005377
# Valor do bias: -0,099452
#
# Treinamento do modelo na iteração 78:
# Previsões antes da função de ativação sigmóide: 0,151078; 0,390854; 0,638696; 0,159143; 1,118248; ...
# Previsões depois da função de ativação sigmóide: 0,537698; 0,596488; 0,654458; 0,539702; 0,753663; ...
# Erros do modelo: 0,537698; 0,596488; -0,345542; 0,539702; -0,246337; ...
# Valores de pesos:
# 1. 0,239125
# 2. 0,004280
# Valor do bias: -0,100915
#
# Treinamento do modelo na iteração 79:
# Previsões antes da função de ativação sigmóide: 0,148911; 0,390177; 0,637863; 0,155332; 1,120394; ...
# Previsões depois da função de ativação sigmóide: 0,537159; 0,596325; 0,654270; 0,538755; 0,754062; ...
# Erros do modelo: 0,537159; 0,596325; -0,345730; 0,538755; -0,245938; ...
# Valores de pesos:
# 1. 0,241159
# 2. 0,003185
# Valor do bias: -0,102376
#
# Treinamento do modelo na iteração 80:
# Previsões antes da função de ativação sigmóide: 0,146745; 0,389496; 0,637025; 0,151522; 1,122527; ...
# Previsões depois da função de ativação sigmóide: 0,536620; 0,596161; 0,654081; 0,537808; 0,754457; ...
# Erros do modelo: 0,536620; 0,596161; -0,345919; 0,537808; -0,245543; ...
# Valores de pesos:
# 1. 0,243188
# 2. 0,002091
# Valor do bias: -0,103836
#
# Treinamento do modelo na iteração 81:
# Previsões antes da função de ativação sigmóide: 0,144578; 0,388812; 0,636181; 0,147714; 1,124648; ...
# Previsões depois da função de ativação sigmóide: 0,536082; 0,595997; 0,653890; 0,536862; 0,754850; ...
# Erros do modelo: 0,536082; 0,595997; -0,346110; 0,536862; -0,245150; ...
# Valores de pesos:
# 1. 0,245213
# 2. 0,000998
# Valor do bias: -0,105295
#
# Treinamento do modelo na iteração 82:
# Previsões antes da função de ativação sigmóide: 0,142412; 0,388124; 0,635333; 0,143909; 1,126756; ...
# Previsões depois da função de ativação sigmóide: 0,535543; 0,595831; 0,653698; 0,535915; 0,755240; ...
# Erros do modelo: 0,535543; 0,595831; -0,346302; 0,535915; -0,244760; ...
# Valores de pesos:
# 1. 0,247234
# 2. -0,000094
# Valor do bias: -0,106752
#
# Treinamento do modelo na iteração 83:
# Previsões antes da função de ativação sigmóide: 0,140247; 0,387434; 0,634480; 0,140107; 1,128853; ...
# Previsões depois da função de ativação sigmóide: 0,535004; 0,595665; 0,653505; 0,534969; 0,755627; ...
# Erros do modelo: 0,535004; 0,595665; -0,346495; 0,534969; -0,244373; ...
# Valores de pesos:
# 1. 0,249250
# 2. -0,001184
# Valor do bias: -0,108207
#
# Treinamento do modelo na iteração 84:
# Previsões antes da função de ativação sigmóide: 0,138083; 0,386742; 0,633624; 0,136307; 1,130940; ...
# Previsões depois da função de ativação sigmóide: 0,534466; 0,595498; 0,653311; 0,534024; 0,756012; ...
# Erros do modelo: 0,534466; 0,595498; -0,346689; 0,534024; -0,243988; ...
# Valores de pesos:
# 1. 0,251263
# 2. -0,002273
# Valor do bias: -0,109660
#
# Treinamento do modelo na iteração 85:
# Previsões antes da função de ativação sigmóide: 0,135921; 0,386047; 0,632765; 0,132512; 1,133018; ...
# Previsões depois da função de ativação sigmóide: 0,533928; 0,595331; 0,653116; 0,533080; 0,756395; ...
# Erros do modelo: 0,533928; 0,595331; -0,346884; 0,533080; -0,243605; ...
# Valores de pesos:
# 1. 0,253271
# 2. -0,003360
# Valor do bias: -0,111112
#
# Treinamento do modelo na iteração 86:
# Previsões antes da função de ativação sigmóide: 0,133760; 0,385351; 0,631903; 0,128720; 1,135086; ...
# Previsões depois da função de ativação sigmóide: 0,533390; 0,595163; 0,652921; 0,532136; 0,756776; ...
# Erros do modelo: 0,533390; 0,595163; -0,347079; 0,532136; -0,243224; ...
# Valores de pesos:
# 1. 0,255276
# 2. -0,004445
# Valor do bias: -0,112563
#
# Treinamento do modelo na iteração 87:
# Previsões antes da função de ativação sigmóide: 0,131600; 0,384653; 0,631039; 0,124932; 1,137145; ...
# Previsões depois da função de ativação sigmóide: 0,532853; 0,594995; 0,652725; 0,531192; 0,757155; ...
# Erros do modelo: 0,532853; 0,594995; -0,347275; 0,531192; -0,242845; ...
# Valores de pesos:
# 1. 0,257277
# 2. -0,005529
# Valor do bias: -0,114011
#
# Treinamento do modelo na iteração 88:
# Previsões antes da função de ativação sigmóide: 0,129442; 0,383954; 0,630173; 0,121149; 1,139197; ...
# Previsões depois da função de ativação sigmóide: 0,532315; 0,594826; 0,652529; 0,530250; 0,757532; ...
# Erros do modelo: 0,532315; 0,594826; -0,347471; 0,530250; -0,242468; ...
# Valores de pesos:
# 1. 0,259273
# 2. -0,006611
# Valor do bias: -0,115458
#
# Treinamento do modelo na iteração 89:
# Previsões antes da função de ativação sigmóide: 0,127287; 0,383254; 0,629305; 0,117370; 1,141241; ...
# Previsões depois da função de ativação sigmóide: 0,531779; 0,594658; 0,652332; 0,529309; 0,757907; ...
# Erros do modelo: 0,531779; 0,594658; -0,347668; 0,529309; -0,242093; ...
# Valores de pesos:
# 1. 0,261266
# 2. -0,007692
# Valor do bias: -0,116904
#
# Treinamento do modelo na iteração 90:
# Previsões antes da função de ativação sigmóide: 0,125133; 0,382554; 0,628437; 0,113596; 1,143277; ...
# Previsões depois da função de ativação sigmóide: 0,531243; 0,594489; 0,652135; 0,528368; 0,758281; ...
# Erros do modelo: 0,531243; 0,594489; -0,347865; 0,528368; -0,241719; ...
# Valores de pesos:
# 1. 0,263256
# 2. -0,008770
# Valor do bias: -0,118347
#
# Treinamento do modelo na iteração 91:
# Previsões antes da função de ativação sigmóide: 0,122982; 0,381852; 0,627567; 0,109827; 1,145308; ...
# Previsões depois da função de ativação sigmóide: 0,530707; 0,594320; 0,651938; 0,527429; 0,758653; ...
# Erros do modelo: 0,530707; 0,594320; -0,348062; 0,527429; -0,241347; ...
# Valores de pesos:
# 1. 0,265241
# 2. -0,009847
# Valor do bias: -0,119789
#
# Treinamento do modelo na iteração 92:
# Previsões antes da função de ativação sigmóide: 0,120834; 0,381151; 0,626697; 0,106063; 1,147332; ...
# Previsões depois da função de ativação sigmóide: 0,530172; 0,594151; 0,651740; 0,526491; 0,759023; ...
# Erros do modelo: 0,530172; 0,594151; -0,348260; 0,526491; -0,240977; ...
# Valores de pesos:
# 1. 0,267223
# 2. -0,010922
# Valor do bias: -0,121230
#
# Treinamento do modelo na iteração 93:
# Previsões antes da função de ativação sigmóide: 0,118687; 0,380449; 0,625827; 0,102304; 1,149350; ...
# Previsões depois da função de ativação sigmóide: 0,529637; 0,593981; 0,651543; 0,525554; 0,759392; ...
# Erros do modelo: 0,529637; 0,593981; -0,348457; 0,525554; -0,240608; ...
# Valores de pesos:
# 1. 0,269201
# 2. -0,011995
# Valor do bias: -0,122668
#
# Treinamento do modelo na iteração 94:
# Previsões antes da função de ativação sigmóide: 0,116544; 0,379747; 0,624957; 0,098551; 1,151362; ...
# Previsões depois da função de ativação sigmóide: 0,529103; 0,593812; 0,651345; 0,524618; 0,759760; ...
# Erros do modelo: 0,529103; 0,593812; -0,348655; 0,524618; -0,240240; ...
# Valores de pesos:
# 1. 0,271175
# 2. -0,013067
# Valor do bias: -0,124105
#
# Treinamento do modelo na iteração 95:
# Previsões antes da função de ativação sigmóide: 0,114403; 0,379045; 0,624087; 0,094803; 1,153370; ...
# Previsões depois da função de ativação sigmóide: 0,528570; 0,593643; 0,651147; 0,523683; 0,760126; ...
# Erros do modelo: 0,528570; 0,593643; -0,348853; 0,523683; -0,239874; ...
# Valores de pesos:
# 1. 0,273146
# 2. -0,014136
# Valor do bias: -0,125540
#
# Treinamento do modelo na iteração 96:
# Previsões antes da função de ativação sigmóide: 0,112265; 0,378343; 0,623217; 0,091062; 1,155372; ...
# Previsões depois da função de ativação sigmóide: 0,528037; 0,593473; 0,650950; 0,522750; 0,760491; ...
# Erros do modelo: 0,528037; 0,593473; -0,349050; 0,522750; -0,239509; ...
# Valores de pesos:
# 1. 0,275113
# 2. -0,015203
# Valor do bias: -0,126974
#
# Treinamento do modelo na iteração 97:
# Previsões antes da função de ativação sigmóide: 0,110131; 0,377642; 0,622348; 0,087326; 1,157370; ...
# Previsões depois da função de ativação sigmóide: 0,527505; 0,593304; 0,650752; 0,521818; 0,760854; ...
# Erros do modelo: 0,527505; 0,593304; -0,349248; 0,521818; -0,239146; ...
# Valores de pesos:
# 1. 0,277076
# 2. -0,016269
# Valor do bias: -0,128406
#
# Treinamento do modelo na iteração 98:
# Previsões antes da função de ativação sigmóide: 0,107999; 0,376941; 0,621479; 0,083596; 1,159363; ...
# Previsões depois da função de ativação sigmóide: 0,526973; 0,593135; 0,650555; 0,520887; 0,761217; ...
# Erros do modelo: 0,526973; 0,593135; -0,349445; 0,520887; -0,238783; ...
# Valores de pesos:
# 1. 0,279036
# 2. -0,017332
# Valor do bias: -0,129836
#
# Treinamento do modelo na iteração 99:
# Previsões antes da função de ativação sigmóide: 0,105870; 0,376240; 0,620612; 0,079872; 1,161352; ...
# Previsões depois da função de ativação sigmóide: 0,526443; 0,592966; 0,650358; 0,519957; 0,761578; ...
# Erros do modelo: 0,526443; 0,592966; -0,349642; 0,519957; -0,238422; ...
# Valores de pesos:
# 1. 0,280992
# 2. -0,018393
# Valor do bias: -0,131265
#
# Treinamento do modelo na iteração 100:
# Previsões antes da função de ativação sigmóide: 0,103744; 0,375540; 0,619746; 0,076155; 1,163337; ...
# Previsões depois da função de ativação sigmóide: 0,525913; 0,592797; 0,650161; 0,519029; 0,761938; ...
# Erros do modelo: 0,525913; 0,592797; -0,349839; 0,519029; -0,238062; ...
# Valores de pesos:
# 1. 0,282945
# 2. -0,019453
# Valor do bias: -0,132692
#
# Treinamento do modelo na iteração 101:
# Previsões antes da função de ativação sigmóide: 0,101622; 0,374841; 0,618881; 0,072443; 1,165318; ...
# Previsões depois da função de ativação sigmóide: 0,525384; 0,592628; 0,649964; 0,518103; 0,762298; ...
# Erros do modelo: 0,525384; 0,592628; -0,350036; 0,518103; -0,237702; ...
# Valores de pesos:
# 1. 0,284894
# 2. -0,020510
# Valor do bias: -0,134117
#
# Treinamento do modelo na iteração 102:
# Previsões antes da função de ativação sigmóide: 0,099503; 0,374142; 0,618017; 0,068738; 1,167296; ...
# Previsões depois da função de ativação sigmóide: 0,524855; 0,592460; 0,649767; 0,517178; 0,762656; ...
# Erros do modelo: 0,524855; 0,592460; -0,350233; 0,517178; -0,237344; ...
# Valores de pesos:
# 1. 0,286840
# 2. -0,021565
# Valor do bias: -0,135540
#
# Treinamento do modelo na iteração 103:
# Previsões antes da função de ativação sigmóide: 0,097387; 0,373445; 0,617155; 0,065040; 1,169270; ...
# Previsões depois da função de ativação sigmóide: 0,524328; 0,592291; 0,649571; 0,516254; 0,763013; ...
# Erros do modelo: 0,524328; 0,592291; -0,350429; 0,516254; -0,236987; ...
# Valores de pesos:
# 1. 0,288783
# 2. -0,022618
# Valor do bias: -0,136962
#
# Treinamento do modelo na iteração 104:
# Previsões antes da função de ativação sigmóide: 0,095275; 0,372748; 0,616294; 0,061348; 1,171241; ...
# Previsões depois da função de ativação sigmóide: 0,523801; 0,592123; 0,649375; 0,515332; 0,763369; ...
# Erros do modelo: 0,523801; 0,592123; -0,350625; 0,515332; -0,236631; ...
# Valores de pesos:
# 1. 0,290721
# 2. -0,023669
# Valor do bias: -0,138382
#
# Treinamento do modelo na iteração 105:
# Previsões antes da função de ativação sigmóide: 0,093166; 0,372053; 0,615435; 0,057662; 1,173209; ...
# Previsões depois da função de ativação sigmóide: 0,523275; 0,591955; 0,649180; 0,514411; 0,763724; ...
# Erros do modelo: 0,523275; 0,591955; -0,350820; 0,514411; -0,236276; ...
# Valores de pesos:
# 1. 0,292657
# 2. -0,024718
# Valor do bias: -0,139800
#
# Treinamento do modelo na iteração 106:
# Previsões antes da função de ativação sigmóide: 0,091061; 0,371358; 0,614578; 0,053983; 1,175174; ...
# Previsões depois da função de ativação sigmóide: 0,522749; 0,591787; 0,648984; 0,513492; 0,764079; ...
# Erros do modelo: 0,522749; 0,591787; -0,351016; 0,513492; -0,235921; ...
# Valores de pesos:
# 1. 0,294589
# 2. -0,025765
# Valor do bias: -0,141217
#
# Treinamento do modelo na iteração 107:
# Previsões antes da função de ativação sigmóide: 0,088959; 0,370665; 0,613723; 0,050311; 1,177136; ...
# Previsões depois da função de ativação sigmóide: 0,522225; 0,591620; 0,648790; 0,512575; 0,764432; ...
# Erros do modelo: 0,522225; 0,591620; -0,351210; 0,512575; -0,235568; ...
# Valores de pesos:
# 1. 0,296518
# 2. -0,026810
# Valor do bias: -0,142632
#
# Treinamento do modelo na iteração 108:
# Previsões antes da função de ativação sigmóide: 0,086860; 0,369973; 0,612870; 0,046645; 1,179095; ...
# Previsões depois da função de ativação sigmóide: 0,521701; 0,591452; 0,648595; 0,511659; 0,764785; ...
# Erros do modelo: 0,521701; 0,591452; -0,351405; 0,511659; -0,235215; ...
# Valores de pesos:
# 1. 0,298443
# 2. -0,027853
# Valor do bias: -0,144046
#
# Treinamento do modelo na iteração 109:
# Previsões antes da função de ativação sigmóide: 0,084765; 0,369282; 0,612019; 0,042986; 1,181051; ...
# Previsões depois da função de ativação sigmóide: 0,521179; 0,591285; 0,648401; 0,510745; 0,765137; ...
# Erros do modelo: 0,521179; 0,591285; -0,351599; 0,510745; -0,234863; ...
# Valores de pesos:
# 1. 0,300365
# 2. -0,028893
# Valor do bias: -0,145457
#
# Treinamento do modelo na iteração 110:
# Previsões antes da função de ativação sigmóide: 0,082674; 0,368592; 0,611170; 0,039334; 1,183005; ...
# Previsões depois da função de ativação sigmóide: 0,520657; 0,591119; 0,648207; 0,509832; 0,765488; ...
# Erros do modelo: 0,520657; 0,591119; -0,351793; 0,509832; -0,234512; ...
# Valores de pesos:
# 1. 0,302283
# 2. -0,029932
# Valor do bias: -0,146867
#
# Treinamento do modelo na iteração 111:
# Previsões antes da função de ativação sigmóide: 0,080586; 0,367903; 0,610323; 0,035688; 1,184957; ...
# Previsões depois da função de ativação sigmóide: 0,520136; 0,590952; 0,648014; 0,508921; 0,765838; ...
# Erros do modelo: 0,520136; 0,590952; -0,351986; 0,508921; -0,234162; ...
# Valores de pesos:
# 1. 0,304198
# 2. -0,030968
# Valor do bias: -0,148275
#
# Treinamento do modelo na iteração 112:
# Previsões antes da função de ativação sigmóide: 0,078502; 0,367216; 0,609478; 0,032050; 1,186906; ...
# Previsões depois da função de ativação sigmóide: 0,519615; 0,590786; 0,647822; 0,508012; 0,766187; ...
# Erros do modelo: 0,519615; 0,590786; -0,352178; 0,508012; -0,233813; ...
# Valores de pesos:
# 1. 0,306110
# 2. -0,032003
# Valor do bias: -0,149682
#
# Treinamento do modelo na iteração 113:
# Previsões antes da função de ativação sigmóide: 0,076422; 0,366530; 0,608635; 0,028418; 1,188853; ...
# Previsões depois da função de ativação sigmóide: 0,519096; 0,590620; 0,647629; 0,507104; 0,766536; ...
# Erros do modelo: 0,519096; 0,590620; -0,352371; 0,507104; -0,233464; ...
# Valores de pesos:
# 1. 0,308019
# 2. -0,033035
# Valor do bias: -0,151087
#
# Treinamento do modelo na iteração 114:
# Previsões antes da função de ativação sigmóide: 0,074345; 0,365846; 0,607795; 0,024793; 1,190798; ...
# Previsões depois da função de ativação sigmóide: 0,518578; 0,590455; 0,647438; 0,506198; 0,766884; ...
# Erros do modelo: 0,518578; 0,590455; -0,352562; 0,506198; -0,233116; ...
# Valores de pesos:
# 1. 0,309924
# 2. -0,034065
# Valor do bias: -0,152490
#
# Treinamento do modelo na iteração 115:
# Previsões antes da função de ativação sigmóide: 0,072272; 0,365163; 0,606957; 0,021175; 1,192740; ...
# Previsões depois da função de ativação sigmóide: 0,518060; 0,590290; 0,647246; 0,505293; 0,767231; ...
# Erros do modelo: 0,518060; 0,590290; -0,352754; 0,505293; -0,232769; ...
# Valores de pesos:
# 1. 0,311826
# 2. -0,035093
# Valor do bias: -0,153892
#
# Treinamento do modelo na iteração 116:
# Previsões antes da função de ativação sigmóide: 0,070202; 0,364482; 0,606122; 0,017564; 1,194681; ...
# Previsões depois da função de ativação sigmóide: 0,517543; 0,590125; 0,647056; 0,504391; 0,767577; ...
# Erros do modelo: 0,517543; 0,590125; -0,352944; 0,504391; -0,232423; ...
# Valores de pesos:
# 1. 0,313724
# 2. -0,036118
# Valor do bias: -0,155292
#
# Treinamento do modelo na iteração 117:
# Previsões antes da função de ativação sigmóide: 0,068137; 0,363802; 0,605289; 0,013959; 1,196619; ...
# Previsões depois da função de ativação sigmóide: 0,517028; 0,589960; 0,646865; 0,503490; 0,767923; ...
# Erros do modelo: 0,517028; 0,589960; -0,353135; 0,503490; -0,232077; ...
# Valores de pesos:
# 1. 0,315619
# 2. -0,037142
# Valor do bias: -0,156690
#
# Treinamento do modelo na iteração 118:
# Previsões antes da função de ativação sigmóide: 0,066075; 0,363123; 0,604459; 0,010362; 1,198556; ...
# Previsões depois da função de ativação sigmóide: 0,516513; 0,589796; 0,646676; 0,502590; 0,768268; ...
# Erros do modelo: 0,516513; 0,589796; -0,353324; 0,502590; -0,231732; ...
# Valores de pesos:
# 1. 0,317511
# 2. -0,038163
# Valor do bias: -0,158087
#
# Treinamento do modelo na iteração 119:
# Previsões antes da função de ativação sigmóide: 0,064016; 0,362446; 0,603631; 0,006771; 1,200490; ...
# Previsões depois da função de ativação sigmóide: 0,515999; 0,589632; 0,646486; 0,501693; 0,768612; ...
# Erros do modelo: 0,515999; 0,589632; -0,353514; 0,501693; -0,231388; ...
# Valores de pesos:
# 1. 0,319400
# 2. -0,039183
# Valor do bias: -0,159482
#
# Treinamento do modelo na iteração 120:
# Previsões antes da função de ativação sigmóide: 0,061962; 0,361770; 0,602805; 0,003188; 1,202423; ...
# Previsões depois da função de ativação sigmóide: 0,515485; 0,589469; 0,646298; 0,500797; 0,768955; ...
# Erros do modelo: 0,515485; 0,589469; -0,353702; 0,500797; -0,231045; ...
# Valores de pesos:
# 1. 0,321286
# 2. -0,040200
# Valor do bias: -0,160875
#
# Treinamento do modelo na iteração 121:
# Previsões antes da função de ativação sigmóide: 0,059911; 0,361096; 0,601982; -0,000389; 1,204354; ...
# Previsões depois da função de ativação sigmóide: 0,514973; 0,589306; 0,646110; 0,499903; 0,769298; ...
# Erros do modelo: 0,514973; 0,589306; -0,353890; 0,499903; -0,230702; ...
# Valores de pesos:
# 1. 0,323168
# 2. -0,041215
# Valor do bias: -0,162267
#
# Treinamento do modelo na iteração 122:
# Previsões antes da função de ativação sigmóide: 0,057864; 0,360424; 0,601162; -0,003959; 1,206283; ...
# Previsões depois da função de ativação sigmóide: 0,514462; 0,589143; 0,645922; 0,499010; 0,769640; ...
# Erros do modelo: 0,514462; 0,589143; -0,354078; 0,499010; -0,230360; ...
# Valores de pesos:
# 1. 0,325047
# 2. -0,042228
# Valor do bias: -0,163657
#
# Treinamento do modelo na iteração 123:
# Previsões antes da função de ativação sigmóide: 0,055820; 0,359753; 0,600344; -0,007521; 1,208210; ...
# Previsões depois da função de ativação sigmóide: 0,513951; 0,588981; 0,645735; 0,498120; 0,769982; ...
# Erros do modelo: 0,513951; 0,588981; -0,354265; 0,498120; -0,230018; ...
# Valores de pesos:
# 1. 0,326923
# 2. -0,043239
# Valor do bias: -0,165045
#
# Treinamento do modelo na iteração 124:
# Previsões antes da função de ativação sigmóide: 0,053781; 0,359084; 0,599529; -0,011077; 1,210135; ...
# Previsões depois da função de ativação sigmóide: 0,513442; 0,588819; 0,645548; 0,497231; 0,770323; ...
# Erros do modelo: 0,513442; 0,588819; -0,354452; 0,497231; -0,229677; ...
# Valores de pesos:
# 1. 0,328795
# 2. -0,044247
# Valor do bias: -0,166432
#
# Treinamento do modelo na iteração 125:
# Previsões antes da função de ativação sigmóide: 0,051745; 0,358416; 0,598716; -0,014626; 1,212059; ...
# Previsões depois da função de ativação sigmóide: 0,512933; 0,588657; 0,645363; 0,496344; 0,770663; ...
# ...
# 1. 1,231200
# 2. -0,463955
# Valor do bias: -0,983820
#
# Treinamento do modelo na iteração 960:
# Previsões antes da função de ativação sigmóide: -0,912507; 0,086715; 0,390005; -1,608439; 2,388450; ...
# Previsões depois da função de ativação sigmóide: 0,286487; 0,521665; 0,596284; 0,166806; 0,915942; ...
# Erros do modelo: 0,286487; 0,521665; -0,403716; 0,166806; -0,084058; ...
# Valores de pesos:
# 1. 1,231833
# 2. -0,464187
# Valor do bias: -0,984564
#
# Treinamento do modelo na iteração 961:
# Previsões antes da função de ativação sigmóide: -0,913199; 0,086541; 0,390000; -1,609479; 2,389479; ...
# Previsões depois da função de ativação sigmóide: 0,286346; 0,521622; 0,596283; 0,166661; 0,916021; ...
# Erros do modelo: 0,286346; 0,521622; -0,403717; 0,166661; -0,083979; ...
# Valores de pesos:
# 1. 1,232466
# 2. -0,464419
# Valor do bias: -0,985308
#
# Treinamento do modelo na iteração 962:
# Previsões antes da função de ativação sigmóide: -0,913890; 0,086367; 0,389994; -1,610518; 2,390507; ...
# Previsões depois da função de ativação sigmóide: 0,286205; 0,521578; 0,596281; 0,166517; 0,916100; ...
# Erros do modelo: 0,286205; 0,521578; -0,403719; 0,166517; -0,083900; ...
# Valores de pesos:
# 1. 1,233098
# 2. -0,464651
# Valor do bias: -0,986051
#
# Treinamento do modelo na iteração 963:
# Previsões antes da função de ativação sigmóide: -0,914580; 0,086193; 0,389989; -1,611556; 2,391534; ...
# Previsões depois da função de ativação sigmóide: 0,286064; 0,521535; 0,596280; 0,166373; 0,916179; ...
# Erros do modelo: 0,286064; 0,521535; -0,403720; 0,166373; -0,083821; ...
# Valores de pesos:
# 1. 1,233730
# 2. -0,464882
# Valor do bias: -0,986794
#
# Treinamento do modelo na iteração 964:
# Previsões antes da função de ativação sigmóide: -0,915270; 0,086019; 0,389984; -1,612593; 2,392561; ...
# Previsões depois da função de ativação sigmóide: 0,285923; 0,521491; 0,596279; 0,166229; 0,916258; ...
# Erros do modelo: 0,285923; 0,521491; -0,403721; 0,166229; -0,083742; ...
# Valores de pesos:
# 1. 1,234361
# 2. -0,465113
# Valor do bias: -0,987536
#
# Treinamento do modelo na iteração 965:
# Previsões antes da função de ativação sigmóide: -0,915959; 0,085845; 0,389979; -1,613629; 2,393587; ...
# Previsões depois da função de ativação sigmóide: 0,285782; 0,521448; 0,596278; 0,166086; 0,916337; ...
# Erros do modelo: 0,285782; 0,521448; -0,403722; 0,166086; -0,083663; ...
# Valores de pesos:
# 1. 1,234991
# 2. -0,465344
# Valor do bias: -0,988278
#
# Treinamento do modelo na iteração 966:
# Previsões antes da função de ativação sigmóide: -0,916647; 0,085672; 0,389975; -1,614663; 2,394613; ...
# Previsões depois da função de ativação sigmóide: 0,285642; 0,521405; 0,596277; 0,165942; 0,916415; ...
# Erros do modelo: 0,285642; 0,521405; -0,403723; 0,165942; -0,083585; ...
# Valores de pesos:
# 1. 1,235621
# 2. -0,465574
# Valor do bias: -0,989020
#
# Treinamento do modelo na iteração 967:
# Previsões antes da função de ativação sigmóide: -0,917336; 0,085498; 0,389970; -1,615697; 2,395637; ...
# Previsões depois da função de ativação sigmóide: 0,285501; 0,521362; 0,596275; 0,165799; 0,916494; ...
# Erros do modelo: 0,285501; 0,521362; -0,403725; 0,165799; -0,083506; ...
# Valores de pesos:
# 1. 1,236250
# 2. -0,465804
# Valor do bias: -0,989762
#
# Treinamento do modelo na iteração 968:
# Previsões antes da função de ativação sigmóide: -0,918023; 0,085325; 0,389966; -1,616730; 2,396662; ...
# Previsões depois da função de ativação sigmóide: 0,285361; 0,521318; 0,596274; 0,165657; 0,916572; ...
# Erros do modelo: 0,285361; 0,521318; -0,403726; 0,165657; -0,083428; ...
# Valores de pesos:
# 1. 1,236879
# 2. -0,466034
# Valor do bias: -0,990503
#
# Treinamento do modelo na iteração 969:
# Previsões antes da função de ativação sigmóide: -0,918710; 0,085152; 0,389962; -1,617761; 2,397686; ...
# Previsões depois da função de ativação sigmóide: 0,285221; 0,521275; 0,596274; 0,165514; 0,916651; ...
# Erros do modelo: 0,285221; 0,521275; -0,403726; 0,165514; -0,083349; ...
# Valores de pesos:
# 1. 1,237507
# 2. -0,466264
# Valor do bias: -0,991244
#
# Treinamento do modelo na iteração 970:
# Previsões antes da função de ativação sigmóide: -0,919396; 0,084979; 0,389959; -1,618792; 2,398709; ...
# Previsões depois da função de ativação sigmóide: 0,285081; 0,521232; 0,596273; 0,165372; 0,916729; ...
# Erros do modelo: 0,285081; 0,521232; -0,403727; 0,165372; -0,083271; ...
# Valores de pesos:
# 1. 1,238134
# 2. -0,466493
# Valor do bias: -0,991985
#
# Treinamento do modelo na iteração 971:
# Previsões antes da função de ativação sigmóide: -0,920082; 0,084806; 0,389955; -1,619821; 2,399731; ...
# Previsões depois da função de ativação sigmóide: 0,284941; 0,521189; 0,596272; 0,165230; 0,916807; ...
# Erros do modelo: 0,284941; 0,521189; -0,403728; 0,165230; -0,083193; ...
# Valores de pesos:
# 1. 1,238761
# 2. -0,466721
# Valor do bias: -0,992725
#
# Treinamento do modelo na iteração 972:
# Previsões antes da função de ativação sigmóide: -0,920767; 0,084633; 0,389952; -1,620849; 2,400753; ...
# Previsões depois da função de ativação sigmóide: 0,284802; 0,521146; 0,596271; 0,165088; 0,916885; ...
# Erros do modelo: 0,284802; 0,521146; -0,403729; 0,165088; -0,083115; ...
# Valores de pesos:
# 1. 1,239388
# 2. -0,466950
# Valor do bias: -0,993465
#
# Treinamento do modelo na iteração 973:
# Previsões antes da função de ativação sigmóide: -0,921452; 0,084461; 0,389949; -1,621876; 2,401774; ...
# Previsões depois da função de ativação sigmóide: 0,284662; 0,521103; 0,596270; 0,164946; 0,916962; ...
# Erros do modelo: 0,284662; 0,521103; -0,403730; 0,164946; -0,083038; ...
# Valores de pesos:
# 1. 1,240013
# 2. -0,467178
# Valor do bias: -0,994205
#
# Treinamento do modelo na iteração 974:
# Previsões antes da função de ativação sigmóide: -0,922136; 0,084288; 0,389946; -1,622903; 2,402795; ...
# Previsões depois da função de ativação sigmóide: 0,284523; 0,521060; 0,596270; 0,164805; 0,917040; ...
# Erros do modelo: 0,284523; 0,521060; -0,403730; 0,164805; -0,082960; ...
# Valores de pesos:
# 1. 1,240638
# 2. -0,467406
# Valor do bias: -0,994944
#
# Treinamento do modelo na iteração 975:
# Previsões antes da função de ativação sigmóide: -0,922819; 0,084116; 0,389944; -1,623928; 2,403815; ...
# Previsões depois da função de ativação sigmóide: 0,284384; 0,521017; 0,596269; 0,164664; 0,917118; ...
# Erros do modelo: 0,284384; 0,521017; -0,403731; 0,164664; -0,082882; ...
# Valores de pesos:
# 1. 1,241263
# 2. -0,467633
# Valor do bias: -0,995683
#
# Treinamento do modelo na iteração 976:
# Previsões antes da função de ativação sigmóide: -0,923502; 0,083944; 0,389941; -1,624952; 2,404835; ...
# Previsões depois da função de ativação sigmóide: 0,284245; 0,520974; 0,596269; 0,164523; 0,917195; ...
# Erros do modelo: 0,284245; 0,520974; -0,403731; 0,164523; -0,082805; ...
# Valores de pesos:
# 1. 1,241887
# 2. -0,467860
# Valor do bias: -0,996422
#
# Treinamento do modelo na iteração 977:
# Previsões antes da função de ativação sigmóide: -0,924185; 0,083772; 0,389939; -1,625975; 2,405853; ...
# Previsões depois da função de ativação sigmóide: 0,284106; 0,520931; 0,596268; 0,164383; 0,917272; ...
# Erros do modelo: 0,284106; 0,520931; -0,403732; 0,164383; -0,082728; ...
# Valores de pesos:
# 1. 1,242511
# 2. -0,468087
# Valor do bias: -0,997160
#
# Treinamento do modelo na iteração 978:
# Previsões antes da função de ativação sigmóide: -0,924867; 0,083601; 0,389937; -1,626997; 2,406872; ...
# Previsões depois da função de ativação sigmóide: 0,283967; 0,520888; 0,596268; 0,164242; 0,917350; ...
# Erros do modelo: 0,283967; 0,520888; -0,403732; 0,164242; -0,082650; ...
# Valores de pesos:
# 1. 1,243133
# 2. -0,468313
# Valor do bias: -0,997898
#
# Treinamento do modelo na iteração 979:
# Previsões antes da função de ativação sigmóide: -0,925548; 0,083429; 0,389936; -1,628018; 2,407889; ...
# Previsões depois da função de ativação sigmóide: 0,283829; 0,520845; 0,596267; 0,164102; 0,917427; ...
# Erros do modelo: 0,283829; 0,520845; -0,403733; 0,164102; -0,082573; ...
# Valores de pesos:
# 1. 1,243756
# 2. -0,468539
# Valor do bias: -0,998636
#
# Treinamento do modelo na iteração 980:
# Previsões antes da função de ativação sigmóide: -0,926229; 0,083257; 0,389934; -1,629038; 2,408906; ...
# Previsões depois da função de ativação sigmóide: 0,283691; 0,520802; 0,596267; 0,163962; 0,917504; ...
# Erros do modelo: 0,283691; 0,520802; -0,403733; 0,163962; -0,082496; ...
# Valores de pesos:
# 1. 1,244377
# 2. -0,468765
# Valor do bias: -0,999373
#
# Treinamento do modelo na iteração 981:
# Previsões antes da função de ativação sigmóide: -0,926909; 0,083086; 0,389933; -1,630056; 2,409923; ...
# Previsões depois da função de ativação sigmóide: 0,283552; 0,520760; 0,596267; 0,163823; 0,917581; ...
# Erros do modelo: 0,283552; 0,520760; -0,403733; 0,163823; -0,082419; ...
# Valores de pesos:
# 1. 1,244999
# 2. -0,468991
# Valor do bias: -1,000111
#
# Treinamento do modelo na iteração 982:
# Previsões antes da função de ativação sigmóide: -0,927588; 0,082915; 0,389932; -1,631074; 2,410939; ...
# Previsões depois da função de ativação sigmóide: 0,283414; 0,520717; 0,596266; 0,163683; 0,917658; ...
# Erros do modelo: 0,283414; 0,520717; -0,403734; 0,163683; -0,082342; ...
# Valores de pesos:
# 1. 1,245619
# 2. -0,469216
# Valor do bias: -1,000847
#
# Treinamento do modelo na iteração 983:
# Previsões antes da função de ativação sigmóide: -0,928267; 0,082744; 0,389932; -1,632091; 2,411954; ...
# Previsões depois da função de ativação sigmóide: 0,283276; 0,520674; 0,596266; 0,163544; 0,917734; ...
# Erros do modelo: 0,283276; 0,520674; -0,403734; 0,163544; -0,082266; ...
# Valores de pesos:
# 1. 1,246239
# 2. -0,469440
# Valor do bias: -1,001584
#
# Treinamento do modelo na iteração 984:
# Previsões antes da função de ativação sigmóide: -0,928946; 0,082573; 0,389931; -1,633107; 2,412969; ...
# Previsões depois da função de ativação sigmóide: 0,283139; 0,520631; 0,596266; 0,163405; 0,917811; ...
# Erros do modelo: 0,283139; 0,520631; -0,403734; 0,163405; -0,082189; ...
# Valores de pesos:
# 1. 1,246859
# 2. -0,469665
# Valor do bias: -1,002320
#
# Treinamento do modelo na iteração 985:
# Previsões antes da função de ativação sigmóide: -0,929624; 0,082402; 0,389931; -1,634121; 2,413983; ...
# Previsões depois da função de ativação sigmóide: 0,283001; 0,520589; 0,596266; 0,163267; 0,917887; ...
# Erros do modelo: 0,283001; 0,520589; -0,403734; 0,163267; -0,082113; ...
# Valores de pesos:
# 1. 1,247477
# 2. -0,469889
# Valor do bias: -1,003056
#
# Treinamento do modelo na iteração 986:
# Previsões antes da função de ativação sigmóide: -0,930301; 0,082232; 0,389931; -1,635135; 2,414996; ...
# Previsões depois da função de ativação sigmóide: 0,282864; 0,520546; 0,596266; 0,163128; 0,917964; ...
# Erros do modelo: 0,282864; 0,520546; -0,403734; 0,163128; -0,082036; ...
# Valores de pesos:
# 1. 1,248096
# 2. -0,470113
# Valor do bias: -1,003791
#
# Treinamento do modelo na iteração 987:
# Previsões antes da função de ativação sigmóide: -0,930978; 0,082061; 0,389931; -1,636148; 2,416009; ...
# Previsões depois da função de ativação sigmóide: 0,282726; 0,520504; 0,596266; 0,162990; 0,918040; ...
# Erros do modelo: 0,282726; 0,520504; -0,403734; 0,162990; -0,081960; ...
# Valores de pesos:
# 1. 1,248713
# 2. -0,470336
# Valor do bias: -1,004527
#
# Treinamento do modelo na iteração 988:
# Previsões antes da função de ativação sigmóide: -0,931654; 0,081891; 0,389931; -1,637159; 2,417022; ...
# Previsões depois da função de ativação sigmóide: 0,282589; 0,520461; 0,596266; 0,162852; 0,918116; ...
# Erros do modelo: 0,282589; 0,520461; -0,403734; 0,162852; -0,081884; ...
# Valores de pesos:
# 1. 1,249331
# 2. -0,470560
# Valor do bias: -1,005262
#
# Treinamento do modelo na iteração 989:
# Previsões antes da função de ativação sigmóide: -0,932330; 0,081721; 0,389932; -1,638170; 2,418033; ...
# Previsões depois da função de ativação sigmóide: 0,282452; 0,520419; 0,596266; 0,162714; 0,918192; ...
# Erros do modelo: 0,282452; 0,520419; -0,403734; 0,162714; -0,081808; ...
# Valores de pesos:
# 1. 1,249947
# 2. -0,470783
# Valor do bias: -1,005996
#
# Treinamento do modelo na iteração 990:
# Previsões antes da função de ativação sigmóide: -0,933005; 0,081551; 0,389933; -1,639179; 2,419044; ...
# Previsões depois da função de ativação sigmóide: 0,282315; 0,520376; 0,596266; 0,162577; 0,918268; ...
# Erros do modelo: 0,282315; 0,520376; -0,403734; 0,162577; -0,081732; ...
# Valores de pesos:
# 1. 1,250563
# 2. -0,471005
# Valor do bias: -1,006730
#
# Treinamento do modelo na iteração 991:
# Previsões antes da função de ativação sigmóide: -0,933680; 0,081381; 0,389934; -1,640188; 2,420055; ...
# Previsões depois da função de ativação sigmóide: 0,282179; 0,520334; 0,596267; 0,162440; 0,918344; ...
# Erros do modelo: 0,282179; 0,520334; -0,403733; 0,162440; -0,081656; ...
# Valores de pesos:
# 1. 1,251179
# 2. -0,471227
# Valor do bias: -1,007464
#
# Treinamento do modelo na iteração 992:
# Previsões antes da função de ativação sigmóide: -0,934354; 0,081211; 0,389935; -1,641195; 2,421065; ...
# Previsões depois da função de ativação sigmóide: 0,282042; 0,520292; 0,596267; 0,162303; 0,918419; ...
# Erros do modelo: 0,282042; 0,520292; -0,403733; 0,162303; -0,081581; ...
# Valores de pesos:
# 1. 1,251794
# 2. -0,471449
# Valor do bias: -1,008198
#
# Treinamento do modelo na iteração 993:
# Previsões antes da função de ativação sigmóide: -0,935028; 0,081041; 0,389936; -1,642201; 2,422074; ...
# Previsões depois da função de ativação sigmóide: 0,281906; 0,520249; 0,596267; 0,162166; 0,918495; ...
# Erros do modelo: 0,281906; 0,520249; -0,403733; 0,162166; -0,081505; ...
# Valores de pesos:
# 1. 1,252408
# 2. -0,471671
# Valor do bias: -1,008931
#
# Treinamento do modelo na iteração 994:
# Previsões antes da função de ativação sigmóide: -0,935701; 0,080872; 0,389938; -1,643207; 2,423083; ...
# Previsões depois da função de ativação sigmóide: 0,281770; 0,520207; 0,596268; 0,162029; 0,918571; ...
# Erros do modelo: 0,281770; 0,520207; -0,403732; 0,162029; -0,081429; ...
# Valores de pesos:
# 1. 1,253022
# 2. -0,471892
# Valor do bias: -1,009664
#
# Treinamento do modelo na iteração 995:
# Previsões antes da função de ativação sigmóide: -0,936373; 0,080702; 0,389940; -1,644211; 2,424091; ...
# Previsões depois da função de ativação sigmóide: 0,281634; 0,520165; 0,596268; 0,161893; 0,918646; ...
# Erros do modelo: 0,281634; 0,520165; -0,403732; 0,161893; -0,081354; ...
# Valores de pesos:
# 1. 1,253635
# 2. -0,472113
# Valor do bias: -1,010397
#
# Treinamento do modelo na iteração 996:
# Previsões antes da função de ativação sigmóide: -0,937045; 0,080533; 0,389942; -1,645215; 2,425099; ...
# Previsões depois da função de ativação sigmóide: 0,281498; 0,520122; 0,596269; 0,161757; 0,918721; ...
# Erros do modelo: 0,281498; 0,520122; -0,403731; 0,161757; -0,081279; ...
# Valores de pesos:
# 1. 1,254247
# 2. -0,472334
# Valor do bias: -1,011130
#
# Treinamento do modelo na iteração 997:
# Previsões antes da função de ativação sigmóide: -0,937716; 0,080364; 0,389944; -1,646217; 2,426106; ...
# Previsões depois da função de ativação sigmóide: 0,281362; 0,520080; 0,596269; 0,161621; 0,918796; ...
# Erros do modelo: 0,281362; 0,520080; -0,403731; 0,161621; -0,081204; ...
# Valores de pesos:
# 1. 1,254860
# 2. -0,472554
# Valor do bias: -1,011862
#
# Treinamento do modelo na iteração 998:
# Previsões antes da função de ativação sigmóide: -0,938387; 0,080195; 0,389947; -1,647218; 2,427112; ...
# Previsões depois da função de ativação sigmóide: 0,281226; 0,520038; 0,596270; 0,161485; 0,918871; ...
# Erros do modelo: 0,281226; 0,520038; -0,403730; 0,161485; -0,081129; ...
# Valores de pesos:
# 1. 1,255471
# 2. -0,472774
# Valor do bias: -1,012593
#
# Treinamento do modelo na iteração 999:
# Previsões antes da função de ativação sigmóide: -0,939058; 0,080027; 0,389950; -1,648219; 2,428118; ...
# Previsões depois da função de ativação sigmóide: 0,281091; 0,519996; 0,596271; 0,161350; 0,918946; ...
# Erros do modelo: 0,281091; 0,519996; -0,403729; 0,161350; -0,081054; ...
# Valores de pesos:
# 1. 1,256082
# 2. -0,472994
# Valor do bias: -1,013325
#
# Treinamento do modelo na iteração 1000:
# Previsões antes da função de ativação sigmóide: -0,939727; 0,079858; 0,389953; -1,649218; 2,429123; ...
# Previsões depois da função de ativação sigmóide: 0,280956; 0,519954; 0,596271; 0,161215; 0,919021; ...
# Erros do modelo: 0,280956; 0,519954; -0,403729; 0,161215; -0,080979; ...
# Valores de pesos:
# 1. 1,256693
# 2. -0,473213
# Valor do bias: -1,014056
#
# Treinamento concluído!

# %% [markdown]
# ## Avaliação do Modelo

# %%
# Separa os dados de entrada para o teste do modelo
dados_entrada_teste = dados_entrada[6:]
dados_entrada_teste
# Out:
# [[1.5, 2], [4, 5.5]]

# %%
# Separa os dados de saída para o teste do modelo
dados_saida_teste = dados_saida[6:]
dados_saida_teste
# Out:
# [0, 1]

# %%
# Realiza as previsões com os dados de teste
previsoes_teste = modelo.previsao(dados_entrada_teste)
# Out:
# Previsões antes da função de ativação sigmóide: -0,075444; 1,410042
# Previsões depois da função de ativação sigmóide: 0,481148; 0,803772
# Previsões das classes depois de realizar o cut-off: 0; 1

# %%
# Avalia os resultados das previsões
for i, previsao in enumerate(previsoes_teste):
    entrada = dados_entrada_teste[i]
    saida = dados_saida_teste[i]
    
    if previsao == 0:
        print(f'\nEntrada {"; ".join([f"{e:_.6f}" for e in entrada])} e saída {saida} a previsão foi {previsao}: Não é Transação Suspeita'.replace('.', ',').replace('_', '.'))
    else:
        print(f'\nEntrada {"; ".join([f"{e:_.6f}" for e in entrada])} e saida {saida} a previsão foi {previsao}: É Transação Suspeita'.replace('.', ',').replace('_', '.'))
# Out:
# Entrada 1,500000; 2,000000 e saída 0 a previsão foi 0: Não é Transação Suspeita
#
# Entrada 4,000000; 5,500000 e saida 1 a previsão foi 1: É Transação Suspeita

# %% [markdown]
# ## Deploy do Modelo

# %%
# Cria matriz com novos dados de entrada
novos_dados = [ [1, 2], [4, 5] ]

# %%
# Faz as previsões com o modelo treinado
previsoes_novos_dados = modelo.previsao(novos_dados)
# Out:
# Previsões antes da função de ativação sigmóide: -0,703790; 1,646648
# Previsões depois da função de ativação sigmóide: 0,330973; 0,838437
# Previsões das classes depois de realizar o cut-off: 0; 1

# %%
# Avalia os resultados das previsões
for i, previsao in enumerate(previsoes_novos_dados):
    entrada = novos_dados[i]
    
    if previsao == 0:
        print(f'\nPara a entrada {"; ".join([f"{e:_.6f}" for e in entrada])} a previsão foi {previsao}: Não é Transação Suspeita'.replace('.', ',').replace('_', '.'))
    else:
        print(f'\nPara a entrada {"; ".join([f"{e:_.6f}" for e in entrada])} a previsão foi {previsao}: É Transação Suspeita'.replace('.', ',').replace('_', '.'))
# Out:
# Para a entrada 1,000000; 2,000000 a previsão foi 0: Não é Transação Suspeita
#
# Para a entrada 4,000000; 5,000000 a previsão foi 1: É Transação Suspeita

# %% [markdown]
# # Fim
